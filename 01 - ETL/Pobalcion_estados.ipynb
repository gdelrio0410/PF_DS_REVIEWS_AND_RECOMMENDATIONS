# %% [markdown]
# ### Base de Datos Población EEUU

# %%
import pandas as pd

# %%
#Leemos el csv de Poblacion de EEUU 
df = pd.read_csv('/Users/julianscarpeccio/Desktop/Data Science HENRY/LABS/PF/ACSDP1Y2021.DP05-2023-09-14T005118.csv')

df
# Out:
#     Label (Grouping)  SEX AND AGE SEX AND AGE!!Total population  \
# 0            Alabama          NaN                           NaN
# 1           Estimate          NaN                     5,039,877
# 2            Percent          NaN                     5,039,877
# 3             Alaska          NaN                           NaN
# 4           Estimate          NaN                       732,673
# ..               ...          ...                           ...
# 151         Estimate          NaN                       578,803
# 152          Percent          NaN                       578,803
# 153      Puerto Rico          NaN                           NaN
# 154         Estimate          NaN                     3,263,584
# 155          Percent          NaN                     3,263,584
#
#     SEX AND AGE!!Total population!!Male SEX AND AGE!!Total population!!Female  \
# 0                                   NaN                                   NaN
# ...

# %%
df = df.drop(columns=['SEX AND AGE'])

# %%
nuevos_nombres = {col: col.replace("SEX AND AGE", "") for col in df.columns}

# Renombra las columnas del DataFrame usando el diccionario
df.rename(columns=nuevos_nombres, inplace=True)
nuevos_nombres = {col: col.replace("!!", " ") for col in df.columns}

# Renombra las columnas del DataFrame usando el diccionario
df.rename(columns=nuevos_nombres, inplace=True)

# %%
df
# Out:
#     Label (Grouping)  Total population  Total population Male  \
# 0            Alabama               NaN                    NaN
# 1           Estimate         5,039,877              2,445,896
# 2            Percent         5,039,877                  48.5%
# 3             Alaska               NaN                    NaN
# 4           Estimate           732,673                383,121
# ..               ...               ...                    ...
# 151         Estimate           578,803                296,007
# 152          Percent           578,803                  51.1%
# 153      Puerto Rico               NaN                    NaN
# 154         Estimate         3,263,584              1,543,991
# 155          Percent         3,263,584                  47.3%
#
#      Total population Female  \
# 0                        NaN
# 1                  2,593,981
# 2                      51.5%
# 3                        NaN
# 4                    349,552
# ..                       ...
# ...

# %%
# Aquí seleccionamos todas las columnas hasta la 5ta.
nombres_columnas = df.columns.tolist() 
df = df.drop(df.columns[5:18], axis=1)

# %%
df = df.drop(df.columns[10:], axis=1)

# %%
df
# Out:
#     Label (Grouping)  Total population  Total population Male  \
# 0            Alabama               NaN                    NaN
# 1           Estimate         5,039,877              2,445,896
# 2            Percent         5,039,877                  48.5%
# 3             Alaska               NaN                    NaN
# 4           Estimate           732,673                383,121
# ..               ...               ...                    ...
# 151         Estimate           578,803                296,007
# 152          Percent           578,803                  51.1%
# 153      Puerto Rico               NaN                    NaN
# 154         Estimate         3,263,584              1,543,991
# 155          Percent         3,263,584                  47.3%
#
#      Total population Female  \
# 0                        NaN
# 1                  2,593,981
# 2                      51.5%
# 3                        NaN
# 4                    349,552
# ..                       ...
# ...

# %%
df.iloc[:, 1:] = df.iloc[:, 1:].apply(lambda x: x.shift(-1))
df = df.iloc[::3]
df = df.reset_index(drop=True)

# %%
df
# Out:
#         Label (Grouping)  Total population  Total population Male  \
# 0                Alabama         5,039,877              2,445,896
# 1                 Alaska           732,673                383,121
# 2                Arizona         7,276,316              3,629,620
# 3               Arkansas         3,025,891              1,493,681
# 4             California        39,237,836             19,618,934
# 5               Colorado         5,812,069              2,943,037
# 6            Connecticut         3,605,597              1,768,045
# 7               Delaware         1,003,384                485,908
# 8   District of Columbia           670,050                319,025
# 9                Florida        21,781,128             10,714,520
# 10               Georgia        10,799,566              5,270,144
# 11                Hawaii         1,441,553                725,604
# 12                 Idaho         1,900,923                954,313
# ...

# %%
df.rename(columns={'Label (Grouping)': 'Estado'}, inplace=True)

# %%
df
# Out:
#                   Estado  Total population  Total population Male  \
# 0                Alabama         5,039,877              2,445,896
# 1                 Alaska           732,673                383,121
# 2                Arizona         7,276,316              3,629,620
# 3               Arkansas         3,025,891              1,493,681
# 4             California        39,237,836             19,618,934
# 5               Colorado         5,812,069              2,943,037
# 6            Connecticut         3,605,597              1,768,045
# 7               Delaware         1,003,384                485,908
# 8   District of Columbia           670,050                319,025
# 9                Florida        21,781,128             10,714,520
# 10               Georgia        10,799,566              5,270,144
# 11                Hawaii         1,441,553                725,604
# 12                 Idaho         1,900,923                954,313
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Estado                                               52 non-null     object
#  1    Total population                                    52 non-null     object
#  2    Total population Male                               52 non-null     object
#  3    Total population Female                             52 non-null     object
#  4    Total population Sex ratio (males per 100 females)  52 non-null     object
#  5    Total population Median age (years)                 52 non-null     object
#  6    Total population Under 18 years                     52 non-null     object
#  7    Total population 16 years and over                  52 non-null     object
# ...

# %%
for x in range(0, df.shape[1]):
    print(f"La columna {x} es de tipo de dato: {type(df.iloc[0,x])}")
# Out:
# La columna 0 es de tipo de dato: <class 'str'>
# La columna 1 es de tipo de dato: <class 'str'>
# La columna 2 es de tipo de dato: <class 'str'>
# La columna 3 es de tipo de dato: <class 'str'>
# La columna 4 es de tipo de dato: <class 'str'>
# La columna 5 es de tipo de dato: <class 'str'>
# La columna 6 es de tipo de dato: <class 'str'>
# La columna 7 es de tipo de dato: <class 'str'>
# La columna 8 es de tipo de dato: <class 'str'>
# La columna 9 es de tipo de dato: <class 'str'>

# %%
df.to_csv('Population', index= False)

# %%
columnas_a_convertir = ['Total population']
df['Total population'] = df['Total population'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
