# %%
import pandas as pd
import seaborn as sns
import folium

# %%
data_comple=pd.read_csv("Union.csv")
data_comple=data_comple[["Estado","latitude","longitude","category","name"]]

# %%
data_comple.dropna(subset=["category"], inplace=True)

# %%
data_comple.head()
# Out:
#     Estado   latitude  longitude  \
# 0  Alabama  33.381416 -86.807040
# 1  Alabama  33.381416 -86.807040
# 2  Alabama  33.100547 -86.861968
# 3  Alabama  33.100547 -86.861968
# 4  Alabama  32.631013 -85.437473
#
#                                             category  \
# 0                                   Pizza restaurant
# 1                                   Pizza restaurant
# 2  Pizza delivery, Chicken wings restaurant, Pizz...
# 3  Pizza delivery, Chicken wings restaurant, Pizz...
# 4        Asian fusion restaurant, Dessert restaurant
#
#                                               name
# 0  California Pizza Kitchen at Riverchase Galleria
# 1  California Pizza Kitchen at Riverchase Galleria
# 2                                        Pizza Hut
# 3                                        Pizza Hut
# 4                                          Cheetos

# %%
df=data_comple[data_comple['Estado'] == "Florida"]
conteo=pd.DataFrame(df['category'].value_counts().head(5).reset_index())
sns.barplot(y='category', x='count', data=conteo)
conteo
# Out:
# c:\Users\victo\OneDrive\Escritorio\Io\PF_DS_REVIEWS_AND_RECOMMENDATIONS\trt\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\victo\OneDrive\Escritorio\Io\PF_DS_REVIEWS_AND_RECOMMENDATIONS\trt\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\victo\OneDrive\Escritorio\Io\PF_DS_REVIEWS_AND_RECOMMENDATIONS\trt\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
#                                             category  count
# 0  Sandwich shop, Caterer, Fast food restaurant, ...    147
# 1                                 Mexican restaurant    130
# 2                                   Pizza restaurant    125
# 3                                 Chinese restaurant     88
# 4                                American restaurant     82

# %%
# Datos de ejemplo
latitudes =df["latitude"]
longitudes = df["longitude"]

# Crear el mapa centrado en las coordenadas promedio
mapa = folium.Map(location=[sum(latitudes)/len(latitudes), sum(longitudes)/len(longitudes)], zoom_start=5)

# Agregar marcadores al mapa
for lat, lon in zip(latitudes, longitudes):
    folium.Marker([lat, lon]).add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abd1273ea750ad23bbc444a0701cac51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abd1273ea750ad23bbc444a0701cac51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abd1273ea750ad23bbc444a0701cac51 = L.map(
#                 &quot;map_abd1273ea750ad23bbc444a0701cac51&quot;,
#                 {
#                     center: [27.665292832289587, -81.54571563617213],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b620b62f24ed3de8d3f4ac87c681ce0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_3a61802c1be2938942a38ff56d09584a = L.marker(
#                 [29.7269487, -84.9815347],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_f0c4d5795300e58423bb7a429d7bb75e = L.marker(
#                 [29.7269487, -84.9815347],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_65e3d913f4dd63b98239eee9c2743651 = L.marker(
#                 [25.0956367, -80.4384006],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_56c7c4dce63f2596a75996abb85ef2be = L.marker(
#                 [25.0956367, -80.4384006],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_27b27d04c940b228a5c4c64ee3e24e5d = L.marker(
#                 [28.5372008, -81.20873619999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_57ccd8e502d5df07bacfd27f8cb4e193 = L.marker(
#                 [28.5372008, -81.20873619999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_2282a0dc93c12f64fffc3c94b2797756 = L.marker(
#                 [26.3512445, -80.15677099999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_cd3f7d107bc3bb519a356e6a08155c17 = L.marker(
#                 [26.3512445, -80.15677099999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_6af45fa71ec540a438c32e9e7cd578d9 = L.marker(
#                 [25.80792, -80.1943823],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_cd3eebeb94a45548612a59090c2b173e = L.marker(
#                 [25.80792, -80.1943823],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_69f04acf780017656ef97f1713590f41 = L.marker(
#                 [28.4631625, -81.45952559999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_090cd2bdd03013b07ab899ff20730b76 = L.marker(
#                 [28.4631625, -81.45952559999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_8a91ab3ad1f1049d484352b6434b7088 = L.marker(
#                 [25.7697718, -80.31392129999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_e8e9ee97e410200acd0d0bf0b503b3fa = L.marker(
#                 [25.7697718, -80.31392129999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_ce040b2441e87e97f1388d64fdccb0a3 = L.marker(
#                 [28.1284549, -81.6148446],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_2db27489bdb88fe0d691ea14dc3d5bec = L.marker(
#                 [28.1284549, -81.6148446],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_1c7559057b794c38ed15f5077a448989 = L.marker(
#                 [30.2884401, -81.43885089999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_385dc5395da66483f291729b26299b60 = L.marker(
#                 [30.2884401, -81.43885089999999],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_3be60e175b6396fc242fe26abf03be71 = L.marker(
#                 [25.1048678, -80.4310241],
#                 {}
#             ).addTo(map_abd1273ea750ad23bbc444a0701cac51);
#
#
#             var marker_f3f3e5b6c3de29c4166e221f20ca4584 = L.marker(
#                 [25.1048678, -80.4310241],
#                 {}
#             ).

# %%
len(list(df["name"].unique()))
# Out:
# 2942

# %%
categori=df[df["category"] == 'American restaurant']
conteo=pd.DataFrame(categori['name'].value_counts().head(5).reset_index())
#sns.barplot(y='category', x='count', data=conteo)
conteo
# Out:
#                     name  count
# 0                  Bolay      3
# 1           Bogie's Cafe      2
# 2  Mila’s on the Manatee      1
# 3           Alumni Grill      1
# 4    Kitchen Four Twenty      1

# %%
latitudes =categori["latitude"]
longitudes = categori["longitude"]

# Crear el mapa centrado en las coordenadas promedio
mapa = folium.Map(location=[sum(latitudes)/len(latitudes), sum(longitudes)/len(longitudes)], zoom_start=5)

# Agregar marcadores al mapa
for lat, lon in zip(latitudes, longitudes):
    folium.Marker([lat, lon]).add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a95e59d161313a6eec2a57fa2467af90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a95e59d161313a6eec2a57fa2467af90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a95e59d161313a6eec2a57fa2467af90 = L.map(
#                 &quot;map_a95e59d161313a6eec2a57fa2467af90&quot;,
#                 {
#                     center: [27.923814089024386, -81.70754010609754],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b6e84f93f78ad1c18beb62e76b01b74 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_3a62dd56fc3144c3dd7453ae571d8f35 = L.marker(
#                 [25.0956367, -80.4384006],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_0742cba955bceb4b6277a2f56520b479 = L.marker(
#                 [25.0956367, -80.4384006],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_a92b1759b12595042d336342b9087f1e = L.marker(
#                 [28.5572082, -81.3646495],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_64e875d6e9cd92d3560a4955c8f54e79 = L.marker(
#                 [27.8798076, -82.49363319999999],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_0832662c690a96266bb08e9e8f57d43f = L.marker(
#                 [29.223494, -81.0972772],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_6f85b3f4f486e7fa633ae85b36d20129 = L.marker(
#                 [27.6747292, -80.4204426],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_9f8a0e47c6ba9d27dfc4e6f1375cac2a = L.marker(
#                 [25.777707, -80.3706916],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_8b79cbf7ef22cf0dcffa5ffb417445a7 = L.marker(
#                 [28.5461716, -81.37349859999999],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_41339208e8ff9a5600a0815d7a2861bc = L.marker(
#                 [28.2369459, -82.72144589999999],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_46f72cb9a65bee85128faefdbbfac0c0 = L.marker(
#                 [25.6553829, -80.32938349999999],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_4a1970e110f3f9804f0f443df0763b23 = L.marker(
#                 [30.8074661, -85.724825],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_39f8d466906419957a4066db5c3b8bc6 = L.marker(
#                 [25.682545, -80.4559182],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_98c1293c9eeb48aa72ded75a894b55b1 = L.marker(
#                 [25.6631717, -80.4172167],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_a4e024b850980de4dc5ffb2518e4b4e5 = L.marker(
#                 [25.7775106, -80.184461],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_737dc10718572576181388b1c22ce95d = L.marker(
#                 [30.7668867, -86.6699824],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_d4c93086e92a8a0dad7829a363fafb1d = L.marker(
#                 [25.9603166, -80.13708869999999],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_99d7790b87dd347f69cc9e8c517750cb = L.marker(
#                 [27.8004957, -82.63770009999999],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_a1dbeac154ea5fb29a8bb6c20478d2c2 = L.marker(
#                 [28.0191047, -82.76009169999999],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_8e1ccadede78b54434900504c56062a0 = L.marker(
#                 [25.8029274, -80.2552355],
#                 {}
#             ).addTo(map_a95e59d161313a6eec2a57fa2467af90);
#
#
#             var marker_549776e0f0043ca667ee72d991023c1c = L.marker(
#                 [26.6502494, -80.1502505],
#                 {}
#             ).addTo(map_a95e59d16131

# %%
df
# Out:
#         Estado   latitude  longitude  \
# 15721  Florida  29.726949 -84.981535
# 15722  Florida  29.726949 -84.981535
# 15723  Florida  25.095637 -80.438401
# 15724  Florida  25.095637 -80.438401
# 15725  Florida  28.537201 -81.208736
# ...        ...        ...        ...
# 19708  Florida  28.805007 -81.331819
# 19709  Florida  25.777951 -80.214580
# 19710  Florida  30.751061 -85.550260
# 19711  Florida  26.272130 -80.263636
# 19712  Florida  27.721474 -82.739556
#
#                                                 category  \
# 15721               Modern French restaurant, Restaurant
# 15722               Modern French restaurant, Restaurant
# 15723                                American restaurant
# 15724                                American restaurant
# 15725  Sandwich shop, Caterer, Fast food restaurant, ...
# ...                                                  ...
# 19708  Chicken wings restaurant, American restaurant,...
# 19709                              Nicaraguan restaurant
# 19710  Fast food restaurant, Hamburger restaurant, Re...
# 19711               Asian restaurant, Chinese restaurant
# 19712  Fast food restaurant, Breakfast restaurant, Ca...
#
#                                                     name
# 15721  Gormley's on the river | Modern cuisine in his...
# 15722  Gormley's on the river | Modern cuisine in his...
# 15723                                       Bogie's Cafe
# 15724                                       Bogie's Cafe
# 15725                                             Subway
# ...                                                  ...
# 19708                                 Buffalo Wild Wings
# 19709                                           La Guira
# 19710                                            Wendy's
# 19711                          Wong's Chinese Restaurant
# 19712                                        Chick-fil-A
#
# [3992 rows x 5 columns]

# %%
categori
# Out:
#         Estado   latitude  longitude             category  \
# 15723  Florida  25.095637 -80.438401  American restaurant
# 15724  Florida  25.095637 -80.438401  American restaurant
# 15758  Florida  28.557208 -81.364649  American restaurant
# 15813  Florida  27.879808 -82.493633  American restaurant
# 15826  Florida  29.223494 -81.097277  American restaurant
# ...        ...        ...        ...                  ...
# 19330  Florida  29.784965 -82.167816  American restaurant
# 19351  Florida  30.278990 -86.017136  American restaurant
# 19564  Florida  28.303348 -81.349339  American restaurant
# 19650  Florida  26.410390 -80.122198  American restaurant
# 19696  Florida  26.670897 -80.201785  American restaurant
#
#                               name
# 15723                 Bogie's Cafe
# 15724                 Bogie's Cafe
# 15758               Restaurant Ash
# 15813               Hott Mess Cafe
# 15826                  Stonewood's
# ...                            ...
# 19330         FairFoods Restaurant
# 19351  Edward's Fine Food And Wine
# 19564                 Mighty Wings
# 19650                        Bolay
# 19696                        Bolay
#
# [82 rows x 5 columns]

# %%
import folium

# Datos de ejemplo
latitudes =categori["latitude"]
longitudes = categori["longitude"]

# Crear el mapa centrado en las coordenadas promedio
mapa = folium.Map(location=[sum(latitudes)/len(latitudes), sum(longitudes)/len(longitudes)], zoom_start=5)

# Agregar marcadores al mapa
for lat, lon in zip(latitudes, longitudes):
    folium.Marker([lat, lon]).add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96eff53e33eea1e0f6ac2c2931ecd002 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96eff53e33eea1e0f6ac2c2931ecd002&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96eff53e33eea1e0f6ac2c2931ecd002 = L.map(
#                 &quot;map_96eff53e33eea1e0f6ac2c2931ecd002&quot;,
#                 {
#                     center: [27.923814089024386, -81.70754010609754],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_036b22cb0c7c364d5606a51d21d5e0b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_40cb99c7fa2fec1667de18b7331a3ef5 = L.marker(
#                 [25.0956367, -80.4384006],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_7a1a0834055f976864b810e6f2a863e9 = L.marker(
#                 [25.0956367, -80.4384006],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_7eb1496b310c59bb87aa033c1c693610 = L.marker(
#                 [28.5572082, -81.3646495],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_814e52e839c68332697a8738cb4c029b = L.marker(
#                 [27.8798076, -82.49363319999999],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_25f5ef5adfdde670fc27d889723d041b = L.marker(
#                 [29.223494, -81.0972772],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_56bb7db57e79bc2056a5ac729ed9978d = L.marker(
#                 [27.6747292, -80.4204426],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_c5adbfbe99a7dd23524d1d6a81f2476e = L.marker(
#                 [25.777707, -80.3706916],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_7cd3e741594774c1d8b83886ed89be2d = L.marker(
#                 [28.5461716, -81.37349859999999],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_c00112d98d24680ad19c95c146ce2e97 = L.marker(
#                 [28.2369459, -82.72144589999999],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_18307e3f4fa81e84f232f7c955fd3efa = L.marker(
#                 [25.6553829, -80.32938349999999],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_b6315d8d8f32d84620777ceb4a1bd6b8 = L.marker(
#                 [30.8074661, -85.724825],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_c3740d061b91df503959364de056c093 = L.marker(
#                 [25.682545, -80.4559182],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_cdacbdd8d36c5e605784132eab9aac64 = L.marker(
#                 [25.6631717, -80.4172167],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_2e1b075458e770d0d61f40c236d148d5 = L.marker(
#                 [25.7775106, -80.184461],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_e2c0b05887683a5f6999a99371d772a9 = L.marker(
#                 [30.7668867, -86.6699824],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_a04fa972e7ac77c0abcfb6144449677b = L.marker(
#                 [25.9603166, -80.13708869999999],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_49d0fe0d1b1b431e1345fd991a0d6a40 = L.marker(
#                 [27.8004957, -82.63770009999999],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_429f0a5276e61cc59f49d68da7de5f2d = L.marker(
#                 [28.0191047, -82.76009169999999],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_2f779b2950ca0cb706adacbe475bd9c4 = L.marker(
#                 [25.8029274, -80.2552355],
#                 {}
#             ).addTo(map_96eff53e33eea1e0f6ac2c2931ecd002);
#
#
#             var marker_efd5a0388357e3519b4af09465eeb43e = L.marker(
#                 [26.6502494, -80.1502505],
#                 {}
#             ).addTo(map_96eff53e33ee
