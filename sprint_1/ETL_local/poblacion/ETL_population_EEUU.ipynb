# %%
from sys import path
import os
path.append(os.path.realpath("../"))

# %%
# Standard imports
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import folium
import matplotlib.pyplot as plt
# %matplotlib inline

from biblioteca import misFunciones as mf

# %%
population_df = pd.read_csv("../Dataset/DataSet Population EEUU.csv")

# %%
population_df.head(20)
# Out:
#    Label (Grouping)  SEX AND AGE SEX AND AGE!!Total population  \
# 0           Alabama          NaN                           NaN
# 1          Estimate          NaN                     5,039,877
# 2           Percent          NaN                     5,039,877
# 3            Alaska          NaN                           NaN
# 4          Estimate          NaN                       732,673
# 5           Percent          NaN                       732,673
# 6           Arizona          NaN                           NaN
# 7          Estimate          NaN                     7,276,316
# 8           Percent          NaN                     7,276,316
# 9          Arkansas          NaN                           NaN
# 10         Estimate          NaN                     3,025,891
# 11          Percent          NaN                     3,025,891
# 12       California          NaN                           NaN
# 13         Estimate          NaN                    39,237,836
# 14          Percent          NaN                    39,237,836
# 15         Colorado          NaN                           NaN
# 16         Estimate          NaN                     5,812,069
# 17          Percent          NaN                     5,812,069
# 18      Connecticut          NaN                           NaN
# 19         Estimate          NaN                     3,605,597
#
#    SEX AND AGE!!Total population!!Male SEX AND AGE!!Total population!!Female  \
# 0                                  NaN                                   NaN
# 1                            2,445,896                             2,593,981
# 2                                48.5%                                 51.5%
# 3                                  NaN                                   NaN
# 4                              383,121                               349,552
# 5                                52.3%                                 47.7%
# 6                                  NaN                                   NaN
# 7                            3,629,620                             3,646,696
# 8                                49.9%                                 50.1%
# 9                                  NaN                                   NaN
# 10                           1,493,681                             1,532,210
# 11                               49.4%                                 50.6%
# 12                                 NaN                                   NaN
# 13                          19,618,934                            19,618,902
# 14                               50.0%                                 50.0%
# 15                                 NaN                                   NaN
# 16                           2,943,037                             2,869,032
# 17                               50.6%                                 49.4%
# 18                                 NaN                                   NaN
# 19                           1,768,045                             1,837,552
#
#    SEX AND AGE!!Total population!!Sex ratio (males per 100 females)  \
# 0                                                 NaN
# 1                                                94.3
# 2                                                 (X)
# 3                                                 NaN
# 4                                               109.6
# 5                                                 (X)
# 6                                                 NaN
# 7                                                99.5
# 8                                                 (X)
# 9                                                 NaN
# 10                                               97.5
# 11                                                (X)
# 12                                                NaN
# 13                                              100.0
# 14                                                (X)
# 15                                                NaN
# 16                                              102.6
# 17                                                (X)
# 18                                                NaN
# 19                                               96.2
#
#    SEX AND AGE!!Total population!!Under 5 years  \
# 0                                           NaN
# 1                                       290,091
# 2                                          5.8%
# 3                                           NaN
# 4                                        46,198
# 5                                          6.3%
# 6                                           NaN
# 7                                       402,255
# 8                                          5.5%
# 9                                           NaN
# 10                                      179,924
# 11                                         5.9%
# 12                                          NaN
# 13                                    2,210,235
# 14                                         5.6%
# 15                                          NaN
# 16                                      307,837
# 17                                         5.3%
# 18                                          NaN
# 19                                      177,577
#
#    SEX AND AGE!!Total population!!5 to 9 years  \
# 0                                          NaN
# 1                                      298,540
# 2                                         5.9%
# 3                                          NaN
# 4                                       52,071
# 5                                         7.1%
# 6                                          NaN
# 7                                      446,309
# 8                                         6.1%
# 9                                          NaN
# 10                                     196,276
# 11                                        6.5%
# 12                                         NaN
# 13                                   2,358,988
# 14                                        6.0%
# 15                                         NaN
# 16                                     336,492
# 17                                        5.8%
# 18                                         NaN
# 19                                     196,796
#
#    SEX AND AGE!!Total population!!10 to 14 years  \
# 0                                            NaN
# 1                                        337,730
# 2                                           6.7%
# 3                                            NaN
# 4                                         52,507
# 5                                           7.2%
# 6                                            NaN
# 7                                        476,245
# 8                                           6.5%
# 9                                            NaN
# 10                                       204,485
# 11                                          6.8%
# 12                                           NaN
# 13                                     2,647,372
# 14                                          6.7%
# 15                                           NaN
# 16                                       374,046
# 17                                          6.4%
# 18                                           NaN
# 19                                       212,689
#
#    SEX AND AGE!!Total population!!15 to 19 years  ...  \
# 0                                            NaN  ...
# 1                                        338,347  ...
# 2                                           6.7%  ...
# 3                                            NaN  ...
# 4                                         50,263  ...
# 5                                           6.9%  ...
# 6                                            NaN  ...
# 7                                        482,998  ...
# 8                                           6.6%  ...
# 9                                            NaN  ...
# 10                                       206,963  ...
# 11                                          6.8%  ...
# 12                                           NaN  ...
# 13                                     2,579,680  ...
# 14                                          6.6%  ...
# 15                                           NaN  ...
# 16                                       375,792  ...
# 17                                          6.5%  ...
# 18                                           NaN  ...
# 19                                       244,686  ...
#
#    HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone  \
# 0                                                 NaN
# 1                                               1,661
# 2                                                0.0%
# 3                                                 NaN
# 4                                              10,994
# 5                                                1.5%
# 6                                                 NaN
# 7                                              11,269
# 8                                                0.2%
# 9                                                 NaN
# 10                                             11,724
# 11                                               0.4%
# 12                                                NaN
# 13                                            138,488
# 14                                               0.4%
# 15                                                NaN
# 16                                              8,105
# 17                                               0.1%
# 18                                                NaN
# 19                                                703
#
#    HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Some other race alone  \
# 0                                                 NaN
# 1                                              15,944
# 2                                                0.3%
# 3                                                 NaN
# 4                                               3,744
# 5                                                0.5%
# 6                                                 NaN
# 7                                              41,944
# 8                                                0.6%
# 9                                                 NaN
# 10                                              6,550
# 11                                               0.2%
# 12                                                NaN
# 13                                            222,579
# 14                                               0.6%
# 15                                                NaN
# 16                                             35,913
# 17                                               0.6%
# 18                                                NaN
# 19                                             28,071
#
#    HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or more races  \
# 0                                                 NaN
# 1                                             169,344
# 2                                                3.4%
# 3                                                 NaN
# 4                                              75,177
# 5                                               10.3%
# 6                                                 NaN
# 7                                             296,151
# 8                                                4.1%
# 9                                                 NaN
# 10                                            196,206
# 11                                               6.5%
# 12                                                NaN
# 13                                          1,640,703
# 14                                               4.2%
# 15                                                NaN
# 16                                            269,074
# 17                                               4.6%
# 18                                                NaN
# 19                                            148,445
#
#    HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race  \
# 0                                                 NaN
# 1                                              28,472
# 2                                                0.6%
# 3                                                 NaN
# 4                                               8,278
# 5                                                1.1%
# 6                                                 NaN
# 7                                              60,311
# 8                                                0.8%
# 9                                                 NaN
# 10                                             89,774
# 11                                               3.0%
# 12                                                NaN
# 13                                            290,466
# 14                                               0.7%
# 15                                                NaN
# 16                                             78,408
# 17                                               1.3%
# 18                                                NaN
# 19                                             53,679
#
#    HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                 NaN
# 1                                             140,872
# 2                                                2.8%
# 3                                                 NaN
# 4                                              66,899
# 5                                                9.1%
# 6                                                 NaN
# 7                                             235,840
# 8                                                3.2%
# 9                                                 NaN
# 10                                            106,432
# 11                                               3.5%
# 12                                                NaN
# 13                                          1,350,237
# 14                                               3.4%
# 15                                                NaN
# 16                                            190,666
# 17                                               3.3%
# 18                                                NaN
# 19                                             94,766
#
#    Total housing units CITIZEN, VOTING AGE POPULATION  \
# 0                  NaN                            NaN
# 1            2,313,616                            NaN
# 2                  (X)                            NaN
# 3                  NaN                            NaN
# 4              327,889                            NaN
# 5                  (X)                            NaN
# 6                  NaN                            NaN
# 7            3,138,685                            NaN
# 8                  (X)                            NaN
# 9                  NaN                            NaN
# 10           1,380,768                            NaN
# 11                 (X)                            NaN
# 12                 NaN                            NaN
# 13          14,512,149                            NaN
# 14                 (X)                            NaN
# 15                 NaN                            NaN
# 16           2,540,783                            NaN
# 17                 (X)                            NaN
# 18                 NaN                            NaN
# 19           1,536,327                            NaN
#
#    CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population  \
# 0                                                 NaN
# 1                                           3,829,788
# 2                                           3,829,788
# 3                                                 NaN
# 4                                             533,852
# 5                                             533,852
# 6                                                 NaN
# 7                                           5,216,518
# 8                                           5,216,518
# 9                                                 NaN
# 10                                          2,237,649
# 11                                          2,237,649
# 12                                                NaN
# 13                                         26,028,290
# 14                                         26,028,290
# 15                                                NaN
# 16                                          4,303,604
# 17                                          4,303,604
# 18                                                NaN
# 19                                          2,659,979
#
#    CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male  \
# 0                                                 NaN
# 1                                           1,827,345
# 2                                               47.7%
# 3                                                 NaN
# 4                                             281,367
# 5                                               52.7%
# 6                                                 NaN
# 7                                           2,584,180
# 8                                               49.5%
# 9                                                 NaN
# 10                                          1,085,739
# 11                                              48.5%
# 12                                                NaN
# 13                                         12,858,732
# 14                                              49.4%
# 15                                                NaN
# 16                                          2,167,373
# 17                                              50.4%
# 18                                                NaN
# 19                                          1,286,843
#
#    CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female
# 0                                                 NaN
# 1                                           2,002,443
# 2                                               52.3%
# 3                                                 NaN
# 4                                             252,485
# 5                                               47.3%
# 6                                                 NaN
# 7                                           2,632,338
# 8                                               50.5%
# 9                                                 NaN
# 10                                          1,151,910
# 11                                              51.5%
# 12                                                NaN
# 13                                         13,169,558
# 14                                              50.6%
# 15                                                NaN
# 16                                          2,136,231
# 17                                              49.6%
# 18                                                NaN
# 19                                          1,373,136
#
# [20 rows x 95 columns]

# %%
population_modify_df = population_df[["Label (Grouping)", "SEX AND AGE!!Total population"]]

# %%
population_modify_df
# Out:
#     Label (Grouping) SEX AND AGE!!Total population
# 0            Alabama                           NaN
# 1           Estimate                     5,039,877
# 2            Percent                     5,039,877
# 3             Alaska                           NaN
# 4           Estimate                       732,673
# ..               ...                           ...
# 151         Estimate                       578,803
# 152          Percent                       578,803
# 153      Puerto Rico                           NaN
# 154         Estimate                     3,263,584
# 155          Percent                     3,263,584
#
# [156 rows x 2 columns]

# %%
population_modify_df.rename(columns={'Label (Grouping)': 'State'}, inplace=True)
population_modify_df.rename(columns={'SEX AND AGE!!Total population': 'Total population'}, inplace=True)
# Out:
# C:\Users\Pavilion HP\AppData\Local\Temp\ipykernel_7856\375231065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population_modify_df.rename(columns={'Label (Grouping)': 'State'}, inplace=True)
# C:\Users\Pavilion HP\AppData\Local\Temp\ipykernel_7856\375231065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population_modify_df.rename(columns={'SEX AND AGE!!Total population': 'Total population'}, inplace=True)

# %%
population_modify_df
# Out:
#             State Total population
# 0         Alabama              NaN
# 1        Estimate        5,039,877
# 2         Percent        5,039,877
# 3          Alaska              NaN
# 4        Estimate          732,673
# ..            ...              ...
# 151      Estimate          578,803
# 152       Percent          578,803
# 153   Puerto Rico              NaN
# 154      Estimate        3,263,584
# 155       Percent        3,263,584
#
# [156 rows x 2 columns]

# %%
mf.verificarTipoDato(population_modify_df)
# Out:
# La columna 'State' es de tipo de dato: <class 'str'>
# contenido: Alabama
#
# La columna 'Total population' es de tipo de dato: <class 'float'>
# contenido: nan

# %%
nulos_por_columna = population_modify_df.isnull().sum()

print(nulos_por_columna)
# Out:
# State                0
# Total population    52
# dtype: int64

# %%
population_modify_df.iloc[:, 1:] = population_modify_df.iloc[:, 1:].apply(lambda x: x.shift(-1))
population_modify_df = population_modify_df.iloc[::3]
population_modify_df = population_modify_df.reset_index(drop=True)
# Out:
# C:\Users\Pavilion HP\AppData\Local\Temp\ipykernel_7856\3241023002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population_modify_df.iloc[:, 1:] = population_modify_df.iloc[:, 1:].apply(lambda x: x.shift(-1))

# %%
population_modify_df.head()
# Out:
#         State Total population
# 0     Alabama        5,039,877
# 1      Alaska          732,673
# 2     Arizona        7,276,316
# 3    Arkansas        3,025,891
# 4  California       39,237,836

# %%
population_modify_df['Total population'] = population_modify_df['Total population'].str.replace(',', '').astype(int)

# %%
mf.verificarTipoDato(population_modify_df)
# Out:
# La columna 'State' es de tipo de dato: <class 'str'>
# contenido: Alabama
#
# La columna 'Total population' es de tipo de dato: <class 'numpy.int32'>
# contenido: 5039877

# %%
# Crear un mapa de calor
sns.set(style="whitegrid")
plt.figure(figsize=(20, 16))
heatmap = sns.heatmap(population_modify_df.pivot_table(index='State', values='Total population'), annot=True, cmap="YlGnBu")

# Configurar etiquetas y título
plt.xlabel("Total population")
plt.ylabel("State")
plt.title("Population Heatmap")

# Mostrar el mapa de calor
plt.show()

# %%
# # Crear una matriz de datos bidimensional
# heatmap_data = population_modify_df.pivot_table(index='State', values='Total population', aggfunc='sum').values

# # Crear el mapa de calor interactivo con Plotly
# fig = px.imshow(heatmap_data,
#                 labels=dict(x="Total population", y="State"),
#                 x=[population_modify_df['Total population'].min(), population_modify_df['Total population'].max()],
#                 y=population_modify_df['State'],
#                 color_continuous_scale='YlGnBu')

# # Configurar el título
# fig.update_layout(title="Population Heatmap")

# # Mostrar el gráfico interactivo
# fig.show()
