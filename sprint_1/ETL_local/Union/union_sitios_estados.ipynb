# %%
import pandas as pd

# %%
sitio=pd.read_csv("../Sitios_Unidos.csv")

# %%
sitio
# Out:
#          Unnamed: 0                               name  \
# 0                 0                    Porter Pharmacy
# 1                 1                       City Textile
# 2                 2                       San Soo Dang
# 3                 3                       Nova Fabrics
# 4                 4                   Nobel Textile Co
# ...             ...                                ...
# 3025006      274996     The Green Room Of Libertyville
# 3025007      274997           Klein Brothers Packaging
# 3025008      274998               Profiles Hair Design
# 3025009      274999                     Arizona LINE-X
# 3025010      275000  US Forest Services Ranger Station
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1        City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2        San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3        Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4        Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                    ...
# 3025006  The Green Room Of Libertyville, 624 Milwaukee ...
# 3025007  Klein Brothers Packaging, 1515 S Fresno Ave, S...
# 3025008  Profiles Hair Design, 522 N Federal Blvd, Rive...
# 3025009  Arizona LINE-X, 21242 N Black Canyon Hwy #A, P...
# 3025010  US Forest Services Ranger Station, 333 E Main ...
#
#                                        gmap_id  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8
# 1        0x80c2c98c0e3c16fd:0x29ec8a728764fdf9
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3         0x80c2c89923b27a41:0x32041559418d447
# 4        0x80c2c632f933b073:0xc31785961fe826a6
# ...                                        ...
# 3025006  0x880f96c84b0ef57b:0xe75b67b15a2cfdad
# 3025007  0x80901260b5987b39:0x8a5028c253e7bee6
# 3025008  0x8758dd1e2533c991:0x5f6d112918f07dba
# 3025009  0x872b6f6f24aea445:0x22df9e5dd01e67ba
# 3025010  0x875901f1fbd58357:0xed5174d5b088430c
#
#                                                description   latitude  \
# 0                                                      NaN  32.388300
# 1                                                      NaN  34.018891
# 2                                                      NaN  34.058092
# 3                                                      NaN  34.023669
# 4                                                      NaN  34.036694
# ...                                                    ...        ...
# 3025006  Innovative, globally inspired dishes are paire...  42.289450
# 3025007                                                NaN  37.934318
# 3025008                                                NaN  43.029664
# 3025009                                                NaN  33.680066
# 3025010                                                NaN  42.829621
#
#           longitude                                           category  \
# 0        -83.357100                                       ['Pharmacy']
# 1       -118.215290                               ['Textile exporter']
# 2       -118.292130                              ['Korean restaurant']
# 3       -118.232930                                   ['Fabric store']
# 4       -118.249421                                   ['Fabric store']
# ...             ...                                                ...
# 3025006  -87.954386                              ['Restaurant', 'Bar']
# 3025007 -121.313102                               ['Trucking company']
# 3025008 -108.380849                     ['Beauty salon', 'Hair salon']
# 3025009 -112.113367  ['Truck accessories store', 'Powder coating se...
# 3025010 -108.723720                                     ['Campground']
#
#          avg_rating  num_of_reviews price  \
# 0               4.9              16   NaN
# 1               4.5               6   NaN
# 2               4.4              18   NaN
# 3               3.3               6   NaN
# 4               4.3               7   NaN
# ...             ...             ...   ...
# 3025006         4.6             228    $$
# 3025007         4.2               3   NaN
# 3025008         4.7              76   NaN
# 3025009         4.6              24   NaN
# 3025010         4.2              24   NaN
#
#                                                      hours  \
# 0        [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 1                                                      NaN
# 2        [['Thursday', '6:30AM–6PM'], ['Friday', '6:30A...
# 3        [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 4        [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# ...                                                    ...
# 3025006  [['Saturday', '4:30–9PM'], ['Sunday', 'Closed'...
# 3025007  [['Saturday', '10AM–1PM'], ['Sunday', 'Closed'...
# 3025008  [['Saturday', '9AM–4PM'], ['Sunday', 'Closed']...
# 3025009  [['Saturday', 'Closed'], ['Sunday', 'Closed'],...
# 3025010                                                NaN
#
#                                                       MISC  \
# 0        {'Service options': ['In-store shopping', 'Sam...
# 1                                                      NaN
# 2        {'Service options': ['Takeout', 'Dine-in', 'De...
# 3        {'Service options': ['In-store shopping'], 'Pa...
# 4                 {'Service options': ['In-store pickup']}
# ...                                                    ...
# 3025006  {'Service options': ['Curbside pickup', 'No-co...
# 3025007                                                NaN
# 3025008  {'Accessibility': ['Wheelchair accessible entr...
# 3025009  {'Service options': ['In-store shopping'], 'Pa...
# 3025010  {'Accessibility': ['Wheelchair accessible entr...
#
#                           state  \
# 0             Open ⋅ Closes 6PM
# 1                      Open now
# 2             Open ⋅ Closes 6PM
# 3             Open ⋅ Closes 5PM
# 4             Open ⋅ Closes 5PM
# ...                         ...
# 3025006   Closed ⋅ Opens 4:30PM
# 3025007       Open ⋅ Closes 1PM
# 3025008       Open ⋅ Closes 4PM
# 3025009  Closed ⋅ Opens 8AM Mon
# 3025010                     NaN
#
#                                           relative_results  \
# 0        ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 1        ['0x80c2c624136ea88b:0xb0315367ed448771', '0x8...
# 2        ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 3        ['0x80c2c8811477253f:0x23a8a492df1918f7', '0x8...
# 4        ['0x80c2c62c496083d1:0xdefa11317fe870a1', '0x8...
# ...                                                    ...
# 3025006  ['0x880f96c848329bd5:0x5a6609c274091c81', '0x8...
# 3025007  ['0x80900c2bd9b41a37:0x5de883f3a0746a61', '0x8...
# 3025008  ['0x8758dd1ffba87d8f:0xf211a1ebf7297000', '0x8...
# 3025009  ['0x872b6f9d1b41ad95:0x94a335fc923f0987', '0x8...
# 3025010  ['0x8758fe025f4f7419:0xc98c1e92db448cb8', '0x8...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 3025006  https://www.google.com/maps/place//data=!4m2!3...
# 3025007  https://www.google.com/maps/place//data=!4m2!3...
# 3025008  https://www.google.com/maps/place//data=!4m2!3...
# 3025009  https://www.google.com/maps/place//data=!4m2!3...
# 3025010  https://www.google.com/maps/place//data=!4m2!3...
#
# [3025011 rows x 16 columns]

# %%
sitio=sitio[["category","avg_rating","gmap_id","name"]]

# %%
sitio.isnull().count()
# Out:
# category      3025011
# avg_rating    3025011
# gmap_id       3025011
# name          3025011
# dtype: int64

# %%
sitio
# Out:
#                                                   category  avg_rating  \
# 0                                             ['Pharmacy']         4.9
# 1                                     ['Textile exporter']         4.5
# 2                                    ['Korean restaurant']         4.4
# 3                                         ['Fabric store']         3.3
# 4                                         ['Fabric store']         4.3
# ...                                                    ...         ...
# 3025006                              ['Restaurant', 'Bar']         4.6
# 3025007                               ['Trucking company']         4.2
# 3025008                     ['Beauty salon', 'Hair salon']         4.7
# 3025009  ['Truck accessories store', 'Powder coating se...         4.6
# 3025010                                     ['Campground']         4.2
#
#                                        gmap_id  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8
# 1        0x80c2c98c0e3c16fd:0x29ec8a728764fdf9
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3         0x80c2c89923b27a41:0x32041559418d447
# 4        0x80c2c632f933b073:0xc31785961fe826a6
# ...                                        ...
# 3025006  0x880f96c84b0ef57b:0xe75b67b15a2cfdad
# 3025007  0x80901260b5987b39:0x8a5028c253e7bee6
# 3025008  0x8758dd1e2533c991:0x5f6d112918f07dba
# 3025009  0x872b6f6f24aea445:0x22df9e5dd01e67ba
# 3025010  0x875901f1fbd58357:0xed5174d5b088430c
#
#                                       name
# 0                          Porter Pharmacy
# 1                             City Textile
# 2                             San Soo Dang
# 3                             Nova Fabrics
# 4                         Nobel Textile Co
# ...                                    ...
# 3025006     The Green Room Of Libertyville
# 3025007           Klein Brothers Packaging
# 3025008               Profiles Hair Design
# 3025009                     Arizona LINE-X
# 3025010  US Forest Services Ranger Station
#
# [3025011 rows x 4 columns]

# %%
Estado=pd.read_csv("../Estados.csv")

# %%
Estado=Estado[["gmap_id","Estado"]]

# %%
Estado
# Out:
#                                        gmap_id      Estado
# 0        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf     Alabama
# 1        0x886268e8fdc4fd2f:0x746533eb9aa4d4df     Alabama
# 2        0x8889aeaec69d4d49:0xb5c343f9d441acf2     Alabama
# 3        0x88626b2e333be6d9:0x2a00a09a7045984f     Alabama
# 4         0x88890c0ff1fb3a1d:0x2b4463747ed6a8a     Alabama
# ...                                        ...         ...
# 1458618  0x54905ea486e1817f:0xc96b16d3a19c2630  Washington
# 1458619  0x5490f7c23e557ca3:0x9ab5bc936ace4a3b  Washington
# 1458620  0x5490594f83e49d6d:0x4e77bd04e0fd72f8  Washington
# 1458621  0x54905e98e7d5f58d:0xa93f0e72b84ee40b  Washington
# 1458622  0x5490f8388d138169:0xc64616ee8cb521ec  Washington
#
# [1458623 rows x 2 columns]

# %%
Dataframe = pd.merge(Estado,sitio, on='gmap_id')

# %%
Dataframe
# Out:
#                                        gmap_id      Estado  \
# 0        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf     Alabama
# 1        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf     Alabama
# 2        0x886268e8fdc4fd2f:0x746533eb9aa4d4df     Alabama
# 3        0x886268e8fdc4fd2f:0x746533eb9aa4d4df     Alabama
# 4        0x8889aeaec69d4d49:0xb5c343f9d441acf2     Alabama
# ...                                        ...         ...
# 1084599  0x5490550bf74a2a4d:0xdffe9bd523a53f1e  Washington
# 1084600  0x5491004195a77427:0x51bf13430c3ff249  Washington
# 1084601  0x5491014d6fbcd7fd:0xe027823a9d0e4ecf  Washington
# 1084602  0x54923990302cb3c7:0x10f023b56efdb019  Washington
# 1084603  0x54906ab43fffffff:0x69acbd12df532b6c  Washington
#
#                                                   category  avg_rating  \
# 0                                             ['Boutique']         4.6
# 1                                             ['Boutique']         4.6
# 2             ['Baby store', "Children's furniture store"]         3.9
# 3             ['Baby store', "Children's furniture store"]         3.9
# 4        ['Movie rental kiosk', 'DVD store', 'Movie ren...         3.8
# ...                                                    ...         ...
# 1084599                                         ['Church']         4.6
# 1084600                                ['Used car dealer']         4.1
# 1084601                                 ['Clothing store']         4.4
# 1084602  ['Driver and vehicle licensing agency', 'Local...         4.3
# 1084603                         ['Motorcycle parts store']         4.7
#
#                                               name
# 0                                    Purple Peanut
# 1                                    Purple Peanut
# 2                           Posh Mommy & Baby Too!
# 3                           Posh Mommy & Baby Too!
# 4                                           Redbox
# ...                                            ...
# 1084599                           Fellowship Group
# 1084600                       Goodfella's Motor Co
# 1084601                              Thrift Center
# 1084602  Hoquiam Licensing & Transportation Agency
# 1084603                         Dead Center Cycles
#
# [1084604 rows x 5 columns]

# %%
list(Dataframe["category"].unique())
# Out:
# ["['Boutique']",
#  '[\'Baby store\', "Children\'s furniture store"]',
#  "['Movie rental kiosk', 'DVD store', 'Movie rental store']",
#  "['Flooring store', 'Carpet store', 'Rug store', 'Wood and laminate flooring supplier']",
#  "['Social services organization']",
#  "['RV park']",
#  "['Pizza restaurant']",
#  "['Pizza delivery', 'Chicken wings restaurant', 'Pizza restaurant', 'Pizza Takeout']",
#  "['Tax preparation service', 'Accountant', 'Tax consultant', 'Tax preparation']",
#  "['Asian fusion restaurant', 'Dessert restaurant']",
#  "['Apartment building', 'Apartment complex']",
#  "['Mover', 'Moving and storage service', 'Moving supply store', 'Piano moving service']",
#  "['Gas station']",
#  "['Real estate']",
#  "['Dollar store', 'Convenience store', 'Discount store', 'Drug store', 'Grocery store']",
#  "['Bridal shop', 'Formal wear store', 'Tuxedo shop']",
#  '[\'Clothing store\', \'Lingerie store\', "Men\'s clothing store", "Women\'s clothing store"]',
#  "['Chevrolet dealer', 'Car dealer']",
#  "['Beauty supply store']",
#  "['City park']",
#  "['Baseball field']",
#  "['Athletic field']",
#  "['Television repair service']",
#  "['Clothing alteration service']",
#  "['Eye care center', 'Contact lenses supplier']",
#  "['Baptist church']",
#  "['Convenience store']",
#  "['Shipping company', 'Fax service', 'Mailbox rental service', 'Moving supply store', 'Notary public', 'Print shop', 'Shipping and mailing service', 'Shipping service', 'Shredding service']",
#  "['Doctor']",
#  "['Students support association']",
#  "['Shopping mall']",
#  '["Women\'s clothing store"]',
#  "['School']",
#  "['Bait shop', 'Convenience store', 'Fishing store', 'Gas station', 'Sunglasses store']",
#  "['Church of Christ', 'Church']",
#  "['Coffee shop']",
#  "['Clothing store']",
#  "['Pet sitter']",
#  "['Restaurant']",
#  "['Barber shop']",
#  "['Hardware store', 'Home improvement store', 'Paint store', 'Tool store']",
#  "['Fast food restaurant', 'Breakfast restaurant', 'Burrito restaurant', 'Lunch restaurant', 'Takeout Restaurant', 'Mexican restaurant', 'Restaurant', 'Taco restaurant', 'Tex-Mex restaurant', 'Vegetarian restaurant']",
#  "['Building materials store']",
#  nan,
#  "['Hardware store']",
#  "['Auto parts store']",
#  "['Loan agency']",
#  "['Church']",
#  "['Convenience store', 'Gas station']",
#  "['Electric utility company', 'Public utility']",
#  "['Heating contractor', 'Air conditioning contractor', 'Air conditioning repair service', 'Furnace repair service']",
#  "['Cafe', 'Gas station', 'Grocery store']",
#  "['Seafood market']",
#  "['Hair salon']",
#  "['Baptist church', 'Church']",
#  "['Loan agency', 'Car finance and loan company']",
#  "['Used car dealer']",
#  "['Tailor']",
#  "['American restaurant']",
#  '[\'Insurance agency\', \'Auto insurance agency\', \'Home insurance agency\', \'Life insurance agency\', "Renter\'s insurance agency"]',
#  "['Car wash']",
#  "['Property management company']",
#  '[\'Medical Center\', \'Chiropractor\', \'Dentist\', \'Doctor\', \'Gynecologist\', \'Medical laboratory\', \'Mental health service\', "Women\'s health clinic", \'Pediatrician\', \'Pharmacy\']',
#  "['Gift shop']",
#  "['Christmas tree farm', 'Tree farm']",
#  "['Grocery delivery service']",
#  "['Shoe store']",
#  "['Furniture store', 'Appliance store', 'Electronics store', 'Home goods store', 'Lawn mower store', 'Mattress store']",
#  "['Health food restaurant']",
#  "['Shooting range', 'Gun shop', 'Pawn shop']",
#  "['Nail salon']",
#  "['Educational testing service']",
#  "['Resort hotel']",
#  "['Locksmith', 'Emergency locksmith service', 'Service establishment', 'Key duplication service', 'Locks supplier']",
#  "['Mobile phone repair shop', 'Cell phone accessory store', 'Cell phone store']",
#  "['Appliance repair service', 'Service establishment']",
#  "['Insurance agency']",
#  "['Marina', 'Boat repair shop']",
#  "['Boat dealer', 'Boat rental service', 'Boat repair shop', 'Boat storage facility']",
#  "['Tire shop']",
#  "['Internist']",
#  "['Night club', 'Bar']",
#  "['Truck accessories store']",
#  "['Business park', 'Research foundation']",
#  "['Insurance agency', 'Auto insurance agency', 'Home insurance agency']",
#  "['Self-storage facility', 'Trailer rental service', 'Truck rental agency']",
#  "['Hiking area']",
#  "['Chicken restaurant', 'Restaurant']",
#  "['Air conditioning contractor']",
#  "['Cell phone store', 'Electronic parts supplier', 'Electronics store', 'Telecommunications service provider', 'Telephone company']",
#  "['Housing authority']",
#  "['City government office']",
#  "['Social security office']",
#  "['Attorney']",
#  "['Pawn shop', 'Jewelry store']",
#  "['Tobacco shop']",
#  "['Attorney', 'Criminal justice attorney', 'Divorce lawyer', 'Family law attorney', 'Law firm']",
#  "['Family law attorney', 'Criminal justice attorney', 'Divorce lawyer']",
#  "['Stair contractor']",
#  "['Podiatrist']",
#  "['Pharmacy']",
#  "['Motorcycles', 'Professional services']",
#  "['Paint store']",
#  "['Lawn care service', 'Pest control service']",
#  "['Sports complex']",
#  "['Auto body shop']",
#  "['Home builder', 'Custom home builder']",
#  "['Soccer field']",
#  "['River']",
#  "['Motorcycle repair shop', 'ATV repair shop', 'Motor scooter dealer', 'Motorcycle dealer', 'Motorcycle insurance agency', 'Motorcycle parts store', 'Motorcycle shop', 'Suzuki motorcycle dealer', 'Used motorcycle dealer', 'Yamaha motorcycle dealer']",
#  "['Auto body parts supplier']",
#  '[\'Insurance agency\', \'Auto insurance agency\', \'Home insurance agency\', \'Insurance company\', \'Life insurance agency\', \'Motorcycle insurance agency\', "Renter\'s insurance agency"]',
#  "['Window cleaning service', 'Service establishment', 'Gutter cleaning service', 'Pressure washing service']",
#  "['Divorce lawyer', 'Criminal justice attorney', 'Estate planning attorney', 'Family law attorney', 'Personal injury attorney']",
#  "['Tax preparation service', 'Tax consultant']",
#  "['Dentist']",
#  "['HVAC contractor', 'Air conditioning contractor', 'Air conditioning repair service', 'Electrician', 'Furnace repair service', 'Plumber']",
#  "['Medical laboratory', 'Blood testing service', 'Diagnostic center', 'Drug testing service', 'Paternity testing service', 'STD testing service']",
#  "['Massage therapist', 'Sports massage therapist']",
#  "['Electronics repair shop', 'Television repair service']",
#  "['Liquor store', 'Beer store']",
#  "['Church of Christ']",
#  "['Neurologist']",
#  "['Senior citizen center']",
#  "['Family practice physician']",
#  "['Barbecue restaurant']",
#  "['Boutique', 'Gift shop', 'Jewelry exporter', 'Metaphysical supply store', 'Used furniture store']",
#  "['Massage therapist']",
#  "['Apartment rental agency']",
#  "['Sandwich shop']",
#  "['Non-profit organization', 'Adoption agency', 'Foster care service']",
#  "['Liquor store']",
#  "['Bistro']",
#  "['Bar']",
#  "['Cell phone store', 'Electronic parts supplier', 'Electronics store', 'Telephone company']",
#  "['Beauty salon']",
#  "['Auto insurance agency', 'Home insurance agency', 'Insurance agency', 'Life insurance agency']",
#  "['Hair salon', 'Beauty salon']",
#  "['Bail bonds service', 'Service establishment']",
#  "['Dentist', 'Cosmetic dentist', 'Denture care center', 'Emergency dental service', 'Pediatric dentist']",
#  "['Cocktail bar']",
#  "['Optometrist', 'Eye care center']",
#  "['Cosmetic dentist', 'Dental implants provider', 'Dentist']",
#  "['Gym']",
#  "['Thrift store']",
#  "['Religious organization']",
#  "['Water softening equipment supplier', 'Bottled water supplier']",
#  "['Greenhouse']",
#  "['Orthopedic surgeon', 'Orthopedic clinic', 'Sports medicine clinic']",
#  "['Boat repair shop']",
#  "['Dessert shop']",
#  "['Juice shop', 'Raw food restaurant', 'Salad shop', 'Vegan restaurant']",
#  "['Employment agency']",
#  "['Water utility company']",
#  "['Furniture store', 'Interior designer', 'Mattress store', 'Oriental rug store']",
#  "['Gas station', 'Auto repair shop']",
#  "['Dental clinic', 'Cosmetic dentist', 'Dentist', 'Emergency dental service', 'Teeth whitening service']",
#  "['Call center']",
#  "['Cell phone store']",
#  "['Hotel']",
#  "['Sandwich shop', 'Caterer', 'Fast food restaurant', 'Takeout Restaurant', 'Restaurant']",
#  "['Apartment complex']",
#  "['Towing service']",
#  "['Camper shell supplier', 'Marine supply store']",
#  "['Tree service', 'Arborist and tree surgeon', 'Firewood supplier', 'Lawn care service']",
#  "['Auto body shop', 'Auto repair shop']",
#  "['Community center']",
#  "['Furniture store', 'Appliance store', 'Electronics store']",
#  "['Mobile home park']",
#  "['Convenience store', 'ATM', 'Gas station', 'Snack bar']",
#  "['Cafe']",
#  "['Beauty salon', 'Hair salon']",
#  "['Deli', 'Frozen yogurt shop']",
#  "['Stable']",
#  "['Building materials supplier', 'Building materials store', 'Concrete contractor', 'Fastener supplier', 'Insulation contractor', 'Metal supplier', 'Roofing contractor', 'Roofing supply store', 'Steel distributor', 'Truss manufacturer']",
#  "['Dentist', 'Cosmetic dentist', 'Emergency dental service', 'Pediatric dentist', 'Teeth whitening service']",
#  "['Bail bonds service']",
#  "['Orthopedic surgeon']",
#  "['Blood donation center']",
#  "['Dentist', 'Cosmetic dentist', 'Dental clinic', 'Teeth whitening service']",
#  "['Tanning salon']",
#  "['Used appliance store']",
#  "['Cell phone store', 'Telecommunications service provider']",
#  "['Auto upholsterer', 'Auto restoration service', 'Car detailing service', 'Car repair and maintenance', 'Carpet installer', 'Upholstery cleaning service', 'Upholstery shop']",
#  "['Seafood restaurant']",
#  "['Electrical supply store', 'Lighting store']",
#  "['Pest control service']",
#  "['Carpet cleaning service']",
#  "['Bar & grill']",
#  "['Gym', 'Fitness center', 'Personal trainer', 'Physical fitness program', 'Weight loss service']",
#  "['Manufacturer']",
#  "['Recreation center']",
#  "['Hair salon', 'Barber shop', 'Beauty salon', 'Waxing hair removal service']",
#  "['Tire shop', 'Auto parts store', 'Auto repair shop', 'Brake shop', 'Car accessories store', 'Car repair and maintenance', 'Oil change service', 'Truck accessories store', 'Truck repair shop']",
#  "['Dive club']",
#  "['Chicken restaurant', 'American restaurant', 'Cheesesteak restaurant', 'Fast food restaurant']",
#  "['Public golf course', 'Private golf course']",
#  "['Sign shop']",
#  "['Pet boarding service', 'Pet groomer']",
#  "['Physical therapy clinic', 'Rehabilitation center', 'Sports medicine clinic']",
#  "['Pediatric dentist']",
#  "['Electric utility company']",
#  "['Mexican restaurant']",
#  "['Truck rental agency', 'Trailer rental service', 'Van rental agency']",
#  "['Auto repair shop']",
#  "['Pharmacy', 'Health consultant', 'Medical supply store']",
#  "['Mover', 'Piano moving service']",
#  "['Pizza restaurant', 'Italian restaurant', 'Delivery Restaurant', 'Takeout Restaurant', 'Pizza delivery', 'Pizza Takeout']",
#  "['Air conditioning contractor', 'Air conditioning repair service', 'Air conditioning system supplier', 'Heating contractor', 'HVAC contractor']",
#  "['Urgent care center', 'Laboratory']",
#  "['Truck rental agency', 'Moving and storage service', 'Moving supply store', 'Packaging supply store', 'Propane supplier', 'Self-storage facility', 'Trailer rental service', 'Trailer supply store', 'Used truck dealer', 'Van rental agency']",
#  "['Beauty salon', 'Electrolysis hair removal service', 'Facial spa', 'Massage therapist']",
#  "['Cleaners']",
#  "['Brake shop']",
#  "['Italian restaurant', 'Brunch restaurant', 'Cocktail bar', 'Wine bar']",
#  "['Auto glass shop']",
#  '[\'Clothing store\', "Women\'s clothing store"]',
#  "['Public library']",
#  "['Shipping service']",
#  "['Gas station', 'Convenience store']",
#  "['United Methodist church']",
#  "['Animal hospital', 'Emergency veterinarian service', 'Veterinarian']",
#  "['Book store', 'Gift shop']",
#  "['Vaporizer store']",
#  "['Restaurant', 'Chinese restaurant', 'Sushi restaurant']",
#  "['Pet boarding service']",
#  "['Real estate agency']",
#  "['Home builder', 'Real estate developer']",
#  "['Townhouse complex']",
#  "['Nail salon', 'Beauty salon']",
#  "['Salvage yard', 'Junkyard', 'Used auto parts store']",
#  "['Variety store', 'Baby store', 'Candy store', 'Gift shop', 'Gift wrap store', 'Invitation printing service', 'Monogramming service', 'Party store', 'Toy store']",
#  "['Furniture store']",
#  "['Steak house']",
#  "['Criminal justice attorney']",
#  "['Gas station', 'ATM', 'Convenience store', 'Restaurant']",
#  "['Boat builders', 'Boat dealer']",
#  "['Apartment complex', 'Apartment rental agency']",
#  "['Tool store']",
#  "['Emergency room', 'Emergency care service']",
#  "['Veterans organization']",
#  "['Bakery', 'Deli', 'Hamburger restaurant', 'Takeout Restaurant', 'Restaurant', 'Sandwich shop']",
#  "['Drug store', 'Beauty supply store', 'Convenience store', 'Cosmetics store', 'Greeting card shop', 'Perfume store', 'Stationery store']",
#  "['Chiropractor']",
#  "['Pawn shop']",
#  "['Chicken wings restaurant']",
#  "['Pest control service', 'Environmental health service', 'Service establishment', 'Lawn care service']",
#  "['Law firm', 'Bankruptcy attorney']",
#  "['Legal services', 'Criminal justice attorney', 'Employment attorney', 'Law firm', 'Attorney', 'Personal injury attorney', 'Trial attorney']",
#  "['Grocery store']",
#  "['Event venue', 'Wedding venue']",
#  "['Family practice physician', 'Nurse practitioner']",
#  "['Mailbox supplier']",
#  "['Sports bar']",
#  "['Car dealer', 'Truck dealer', 'Used car dealer', 'Used truck dealer']",
#  "['Auto body shop', 'Auto dent removal service', 'Auto restoration service']",
#  "['Mobile phone repair shop', 'Cell phone accessory store', 'Electronics repair shop']",
#  "['Non-denominational church', 'Church']",
#  "['Campground']",
#  "['Denture care center', 'Dentist']",
#  "['Pizza restaurant', 'American restaurant', 'Chicken wings restaurant', 'Sports bar']",
#  "['Jewelry store', 'Diamond dealer', 'Gift shop', 'Jeweler', 'Jewelry designer', 'Jewelry repair service', 'Watch store']",
#  "['Recreation center', 'Park']",
#  "['Real estate rental agency', 'Apartment rental agency', 'Condominium rental agency', 'Property management company', 'Real estate agency']",
#  "['Tire shop', 'Auto air conditioning service', 'Auto spring shop', 'Brake shop', 'Car battery store', 'Car repair and maintenance', 'Mechanic', 'Oil change service', 'Tire repair shop', 'Wheel alignment service']",
#  "['Apartment rental agency', 'Apartment complex', 'Condominium complex', 'Condominium rental agency', 'Property management company', 'Real estate rental agency']",
#  "['Electrical supply store', 'Appliance parts supplier', 'Appliance store', 'Hardware store', 'Plumbing supply store']",
#  "['Record store']",
#  "['Seed supplier']",
#  "['Nail salon', 'Day spa', 'Waxing hair removal service']",
#  "['Carpet cleaning service', 'Upholstery cleaning service']",
#  "['Home inspector', 'Service establishment']",
#  "['Fitness center', 'Gym', 'Personal trainer']",
#  "['Dental clinic']",
#  "['Donut shop']",
#  "['Florist', 'Event planner', 'Garden', 'Home goods store', 'Lighting store', 'Wholesale florist']",
#  "['Pharmacy', 'Medical Center', 'Medical supply store']",
#  "['Paint store', 'Home improvement store', 'Paint manufacturer', 'Painting', 'Paintings store', 'Wallpaper store']",
#  "['Garden center']",
#  "['Dollar store', 'Beauty supply store', 'Discount store', 'Grocery store', 'Party store', 'Pet supply store']",
#  "['Distribution service']",
#  "['Self-storage facility', 'Moving and storage service', 'Storage facility']",
#  "['Immigration attorney']",
#  "['School supply store', 'Educational supply store', 'Religious goods store']",
#  "['Mobile phone repair shop', 'Cell phone store', 'Computer repair service', 'Phone repair service', 'Repair service', 'Website designer']",
#  "['Veterinarian', 'Animal hospital', 'Emergency veterinarian service', 'Pet boarding service']",
#  "['Oil change service', 'Auto repair shop', 'Glass repair service']",
#  "['Loan agency', 'Financial institution', 'Money order service', 'Money transfer service']",
#  "['Park']",
#  "['Lounge', 'Restaurant']",
#  "['Restaurant', 'American restaurant', 'Bar', 'Event venue', 'Fast food restaurant', 'Fine dining restaurant', 'Seafood restaurant', 'Soul food restaurant']",
#  "['Banquet hall']",
#  "['Self-storage facility', 'Moving and storage service', 'Moving supply store', 'Packaging supply store', 'Trailer rental service', 'Trailer supply store', 'Truck rental agency', 'Used truck dealer', 'Van rental agency']",
#  "['Appliance parts supplier']",
#  "['Beauty salon', 'Barber shop']",
#  "['Sports club']",
#  "['Internet service provider', 'Cable company', 'Telecommunications service provider']",
#  "['Department store', 'Gas station']",
#  "['Car dealer', 'Buick dealer', 'GMC dealer', 'Used car dealer', 'Used truck dealer']",
#  "['Jeweler']",
#  "['Florist', 'Flower delivery', 'Flower designer', 'Gift shop']",
#  "['Playground']",
#  '[\'Furniture store\', \'Bedroom furniture store\', "Children\'s furniture store", \'Mattress store\', \'Outdoor furniture store\']',
#  "['Massage therapist', 'Day spa', 'Fitness center', 'Medical spa', 'Spa', 'Spa and health club', 'Sports massage therapist', 'Thai massage therapist', 'Wellness center']",
#  "['Gym', 'Fitness center', 'Physical fitness program', 'Physical therapy clinic', 'Spa and health club', 'Tanning salon']",
#  "['Garbage dump']",
#  "['Athletic track']",
#  "['Public golf course', 'Banquet hall', 'Country club', 'Golf course', 'Golf instructor', 'Wedding venue']",
#  "['Arena']",
#  "['Debris removal service', 'Service establishment', 'Garbage collection service', 'Garbage dump service', 'Waste management service']",
#  "['Consignment shop']",
#  "['Park', 'Tourist attraction']",
#  "['Pain control clinic']",
#  "['Hair salon', 'Beauty salon', 'Nail salon']",
#  "['Real estate rental agency']",
#  "['Auto parts store', 'Auto body parts supplier', 'Car battery store', 'Car repair and maintenance', 'Car stereo store', 'Motorcycle parts store', 'Trailer supply store', 'Truck accessories store']",
#  "['Veterinarian']",
#  "['Self-storage facility', 'Storage facility']",
#  "['Insurance agency', 'Auto insurance agency', 'Home insurance agency', 'Motorcycle insurance agency']",
#  "['Dollar store', 'Craft store', 'Discount store', 'Grocery store', 'Home goods store', 'Kitchen supply store', 'Party store', 'School supply store', 'Toy store', 'Variety store']",
#  "['Trucking company']",
#  "['Newspaper publisher', 'Advertising agency', 'Newspaper advertising department']",
#  "['Cell phone store', 'Computer repair service']",
#  "['Gun shop']",
#  "['Mattress store']",
#  "['Florist']",
#  "['Loan agency', 'Tax preparation service']",
#  "['Auto insurance agency', 'Insurance agency', 'Tax preparation']",
#  "['Self-storage facility']",
#  "['Real estate attorney', 'Title company']",
#  "['Shoe store', 'Clothing store']",
#  "['Storage', 'Self-storage facility', 'Trailer rental service', 'Truck rental agency']",
#  "['Yoga studio']",
#  "['Lutheran church', 'Religious organization']",
#  "['Apartment building']",
#  "['Gas station', 'ATM', 'Convenience store']",
#  "['Wheel alignment service']",
#  "['Karaoke bar', 'Bar']",
#  "['Auto parts store', 'Health']",
#  "['Event venue']",
#  "['Self-storage facility', 'Automobile storage facility', 'Boat storage facility', 'Records storage facility']",
#  "['Thrift store', 'Mission']",
#  "['General practice attorney', 'Bankruptcy attorney', 'Criminal justice attorney', 'Divorce lawyer', 'Elder law attorney', 'Estate planning attorney', 'Family law attorney', 'Real estate attorney']",
#  "['Veterans organization', 'Association or organization']",
#  "['Window installation service', 'Door supplier', 'Roofing contractor', 'Siding contractor', 'Sunroom contractor']",
#  "['Pest control service', 'Service establishment']",
#  "['Gift shop', 'Book store', 'Christian book store', 'Church supply store', 'Religious goods store']",
#  "['Real estate agency', 'Property management company']",
#  "['Cosmetic dentist']",
#  "['Transmission shop']",
#  "['Gun shop', 'Ammunition supplier', 'Army & navy surplus shop', 'Outdoor sports store', 'Police supply store', 'Shooting range']",
#  "['Tattoo and piercing shop']",
#  "['Corporate office']",
#  "['Lutheran church', 'Church']",
#  "['Sporting goods store']",
#  "['Seafood']",
#  "['Medical clinic', 'Doctor', 'Family practice physician']",
#  "['Insurance agency', 'Auto insurance agency']",
#  "['Video arcade']",
#  "['Craft store']",
#  '[\'Clothing store\', "Children\'s clothing store", "Men\'s clothing store", "Women\'s clothing store"]',
#  "['Pet store']",
#  "['Auto wrecker']",
#  "['Business management consultant']",
#  "['Popcorn store', 'Retail space rental agency']",
#  "['Beauty salon', 'Ear piercing service', 'Eyelash salon', 'Hair salon', 'Nail salon']",
#  "['Chicken restaurant']",
#  "['Car detailing service', 'Car wash']",
#  "['Family practice physician', 'Counselor', 'Dentist', 'Doctor', 'Laboratory', 'Medical clinic', 'Medical office', 'Pharmacy']",
#  "['Small engine repair service']",
#  "['Television station']",
#  "['Recycling center']",
#  "['Lawn mower store']",
#  "['Funeral home', 'Casket service', 'Cemetery', 'Coffin supplier', 'Cremation service', 'Funeral director']",
#  "['Building materials supplier']",
#  "['RV park', 'Campground']",
#  "['Auto repair shop', 'Gas station']",
#  "['Grocery store', 'Department store']",
#  "['Self service car wash']",
#  "['Pizza restaurant', 'Pizza Takeout']",
#  "['Bakery']",
#  "['Roller skating rink']",
#  "['Eye care center', 'Contact lenses supplier', 'Optician', 'Optometrist', 'Sunglasses store']",
#  "['Photographer']",
#  "['Restaurant', 'American restaurant']",
#  "['Animal hospital']",
#  "['Mexican grocery store', 'Supermarket']",
#  "['Fireworks store', 'Store']",
#  "['Security guard service', 'Private investigator']",
#  "['Bakery', 'Grocery store', 'Store']",
#  "['Ice cream shop']",
#  "['Obstetrician-gynecologist']",
#  "['Eye care center', 'Lasik surgeon', 'Ophthalmologist']",
#  "['Association or organization', 'Religious organization']",
#  "['Self-storage facility', 'Moving and storage service', 'RV storage facility', 'Trailer rental service', 'Truck rental agency']",
#  "['Skate shop', 'Skateboard shop']",
#  "['House cleaning service', 'Service establishment']",
#  "['Used auto parts store', 'Junkyard', 'Salvage yard', 'Towing service']",
#  "['Fraternal organization']",
#  "['Housing development']",
#  "['Hospital']",
#  "['Mattress store', 'Bedding store', 'Bedroom furniture store', 'Furniture store', 'Home goods store']",
#  "['Western apparel store']",
#  "['Sandwich shop', 'Breakfast restaurant', 'Takeout Restaurant']",
#  "['Tree service', 'Service establishment']",
#  "['Car rental agency', 'Transportation service']",
#  "['Car dealer']",
#  "['Episcopal church']",
#  "['Cigar shop', 'Lounge', 'Social club', 'Tobacco shop', 'Tobacco supplier', 'Wine bar']",
#  "['Cell phone store', 'Cell phone accessory store', 'Mobile phone repair shop', 'Phone repair service']",
#  "['Jewelry store', 'Diamond dealer', 'Jeweler', 'Jewelry appraiser', 'Jewelry buyer', 'Jewelry designer', 'Jewellery manufacturer', 'Jewelry repair service', 'Watch repair service']",
#  "['Jewelry store', 'Diamond dealer', 'Gift shop', 'Goldsmith', 'Jeweler', 'Jewelry repair service', 'Silversmith', 'Watch repair service', 'Watch store']",
#  "['Mexican grocery store']",
#  "['Storage facility']",
#  '[\'Consignment shop\', \'Boutique\', "Children\'s clothing store", \'Furniture store\', \'Home goods store\', "Men\'s clothing store", \'Thrift store\', \'Used clothing store\', "Women\'s clothing store"]',
#  "['Lighting store']",
#  "['Electrical supply store', 'Electrical wholesaler', 'Home improvement store', 'Light bulb supplier', 'Lighting store']",
#  "['Apartment rental agency', 'Apartment building', 'Apartment complex']",
#  "['Bakery', 'Catering']",
#  "['Home goods store']",
#  "['Thrift store', 'Second hand store', 'Used appliance store', 'Used clothing store', 'Used furniture store']",
#  "['Shipping and mailing service', 'Business center', 'Freight forwarding service', 'Mailbox rental service', 'Notary public', 'Office supply store', 'Packaging supply store', 'Print shop', 'Shredding service']",
#  "['Store']",
#  "['Youth organization', 'After school program', 'Recreation center', 'Volunteer organization']",
#  "['Used car dealer', 'Car dealer', 'Truck dealer', 'Used truck dealer']",
#  "['Massage therapist', 'Massage spa', 'Sports massage therapist', 'Wellness center']",
#  "['Dentist', 'Cosmetic dentist', 'Dental clinic', 'Dental implants periodontist', 'Dental implants provider', 'Emergency dental service', 'Teeth whitening service']",
#  "['Electronics repair shop', 'Cell phone store', 'Computer repair service', 'Electronics store', 'Mobile phone repair shop', 'Screen repair service']",
#  "['Urgent care center', 'Emergency care service']",
#  "['Book store', 'Clothing store']",
#  "['Produce market']",
#  "['Movie theater']",
#  "['Scrap metal dealer']",
#  "['Loan agency', 'Check cashing service', 'Money transfer service']",
#  "['Auto body shop', 'Auto glass shop', 'Auto repair shop']",
#  "['Urgent care center', 'Walk-in clinic']",
#  "['Stadium']",
#  '[\'Clothing store\', \'Jeans shop\', \'Dress store\', \'Fashion accessories store\', \'Home goods store\', "Men\'s clothing store", \'Plus size clothing store\', \'Shoe store\', "Women\'s clothing store"]',
#  "['Employment center']",
#  "['Softball club', 'City government office']",
#  "['Prison', 'Historical place', 'Tourist attraction']",
#  "['Chiropractor', 'Massage therapist']",
#  "['Auto repair shop', 'Auto painting', 'Engine rebuilding service', 'Transmission shop']",
#  '[\'Home goods store\', \'Appliance store\', \'Bedroom furniture store\', "Children\'s furniture store", \'Electrical supply store\', \'Furniture rental service\', \'Furniture store\', \'Mattress store\', \'Office furniture store\']',
#  "['Auto repair shop', 'Auto parts store', 'Tire shop']",
#  "['Credit union', 'ATM', 'Bank', 'Business development service', 'Financial planner', 'Mortgage lender']",
#  "['Cocktail bar', 'Night club']",
#  '[\'Insurance agency\', \'Auto insurance agency\', \'Commercial agent\', \'Financial institution\', \'Health insurance agency\', \'Home insurance agency\', \'Life insurance agency\', "Renter\'s insurance agency"]',
#  "['Juice shop']",
#  "['Post office', 'Logistics service', 'Money order service', 'Shipping and mailing service']",
#  "['Loan agency', 'Financial consultant']",
#  "['Auto repair shop', 'Auto radiator repair service', 'Brake shop', 'Oil change service', 'Vehicle inspection']",
#  "['Electric vehicle charging station']",
#  "['Boat dealer']",
#  "['Retirement community']",
#  "['Pet groomer']",
#  "['Mobile home supply store']",
#  "['Fireworks store']",
#  "['Tattoo shop']",
#  "['Apartment complex', 'Property management company', 'Real estate agency']",
#  "['Roofing contractor', 'Building restoration service', 'Construction company', 'Deck builder', 'Door shop', 'Siding contractor', 'Window installation service']",
#  "['Hotel', 'Inn']",
#  "['Association or organization']",
#  "['Carpet store', 'Professional services']",
#  '[\'Insurance agency\', \'Auto insurance agency\', \'Home insurance agency\', \'Insurance broker\', \'Life insurance agency\', \'Motorcycle insurance agency\', "Renter\'s insurance agency"]',
#  "['Bubble tea store']",
#  "['Baptist church', 'Church', 'Professional services']",
#  "['Student dormitory']",
#  "['Disability services & support organisation']",
#  "['Truck repair shop', 'Diesel engine repair service', 'Vehicle inspection']",
#  "['Snack bar']",
#  "['Shoe store', 'Clothing store', 'Sporting goods store']",
#  "['Chicken restaurant', 'Fast food restaurant']",
#  "['Insurance attorney']",
#  "['Auto body shop', 'Towing service']",
#  "['Computer repair service']",
#  "['Party equipment rental service', 'Amusement center', 'Party store', 'Tent rental service']",
#  "['Pet groomer', 'Dog day care center']",
#  "['Surplus store', 'Boot store', 'Collectibles store']",
#  "['Heating contractor', 'Air conditioning contractor']",
#  "['Auto repair shop', 'Auto parts store', 'Car battery store', 'Oil change service', 'Tire shop']",
#  "['Title company']",
#  "['Condominium complex']",
#  "['Dermatologist', 'Doctor']",
#  "['Masonry contractor', 'Building materials supplier', 'Quarry']",
#  "['Legal services']",
#  "['Volleyball club']",
#  "['Eye care center', 'Ophthalmologist', 'Optician', 'Optometrist', 'Surgical center']",
#  "['Marine supply store']",
#  "['Jewelry store', 'Jeweler', 'Jewelry buyer', 'Jewelry repair service', 'Watch repair service']",
#  "['Laundromat']",
#  "['Mobile phone repair shop', 'Cell phone accessory store', 'Cell phone store', 'Electronics repair shop', 'Phone repair service', 'Repair service', 'Screen repair service', 'Store equipment supplier', 'Technical service']",
#  "['Museum', 'Art gallery', 'Event venue', 'Historical landmark', 'Tourist attraction', 'Wedding venue']",
#  "['Mobile home dealer']",
#  "['Antique store', 'Professional services']",
#  "['Dry cleaner']",
#  "['Driving school']",
#  "['Used car dealer', 'Used truck dealer']",
#  "['Motorcycle repair shop', 'ATV dealer', 'ATV repair shop', 'Motorcycle dealer', 'Motorcycle shop', 'Motorsports store', 'Repair service']",
#  "['Public swimming pool']",
#  "['Shoe repair shop']",
#  "['Medical clinic', 'Doctor', 'Obstetrician-gynecologist', 'Medical Center', 'Pediatrician', 'Urologist']",
#  "['Auto repair shop', 'Auto parts store']",
#  "['Plumbing supply store', 'Electrical supply store', 'Hardware store', 'Pipe supplier']",
#  "['Uniform store', 'Business to business service', 'Cleaning products supplier', 'Janitorial equipment supplier', 'Laundry service', 'Protective clothing supplier', 'Safety equipment supplier', 'Work clothes store']",
#  "['Music store', 'Guitar store', 'Karaoke']",
#  "['Hobby store']",
#  "['Hardware store', 'Electrical supply store', 'Home improvement store', 'Lumber store', 'Paint store', 'Plumbing supply store', 'Tool rental service']",
#  "['Drug store', 'Pharmacy']",
#  "['School administrator']",
#  "['Real estate agency', 'Commercial real estate agency', 'Real estate agents', 'Real estate rental agency']",
#  "['Gas company']",
#  "['Property management company', 'Vacation home rental agency']",
#  "['Primary school']",
#  "['Paving contractor']",
#  "['Beauty school']",
#  "['Loan agency', 'Pawn shop']",
#  "['Auto body shop', 'Auto restoration service']",
#  '["Sheriff\'s department"]',
#  "['Construction company']",
#  "['Farm']",
#  "['Plastic surgeon', 'Dermatologist', 'Plastic surgery clinic', 'Surgical center']",
#  "['Sports medicine clinic', 'Doctor', 'Medical clinic', 'Orthopedic surgeon', 'Sports medicine physician', 'Surgeon']",
#  "['Candy store', 'Bakery']",
#  "['Mexican restaurant', 'Latin American restaurant']",
#  "['Chiropractor', 'Alternative medicine practitioner', 'Health food store', 'Holistic medicine practitioner', 'Weight loss service']",
#  "['Optometrist', 'Doctor', 'Optician']",
#  "['Wedding venue', 'Historical place']",
#  "['Beauty supply store', 'Barber supply store', 'Cosmetics store']",
#  "['Car repair and maintenance']",
#  "['Auto repair shop', 'Auto restoration service', 'Used auto parts store']",
#  "['Appliance parts supplier', 'Home goods store']",
#  '[\'Clothing store\', "Men\'s clothing store", \'Shoe store\', \'Sportswear store\', \'Youth clothing store\']',
#  "['Gas station', 'Convenience store', 'Fast food restaurant']",
#  '[\'Clothing store\', "Children\'s clothing store", "Men\'s clothing store", \'Outlet store\', "Women\'s clothing store"]',
#  "['Hair salon', 'Barber shop']",
#  "['Screen printer', 'Custom t-shirt store', 'Graphic designer', 'T-shirt store']",
#  "['Used tire shop']",
#  "['Holiday accommodation service', 'Service establishment']",
#  "['Insurance agency', 'Auto insurance agency', 'Home insurance agency', 'Life insurance agency', 'Motorcycle insurance agency']",
#  "['Assemblies of God church']",
#  "['Japanese steakhouse', 'Caterer', 'Food producer', 'Takeout Restaurant', 'Party planner']",
#  "['Mexican restaurant', 'Burrito restaurant', 'Restaurant', 'Taco restaurant']",
#  "['House cleaning service', 'Commercial cleaning service', 'Janitorial service']",
#  "['Biotechnology company']",
#  "['Physical therapy clinic', 'Physical therapist']",
#  "['Art studio']",
#  "['Country club']",
#  "['Athletic park']",
#  "['Dermatologist', 'Skin care clinic']",
#  "['Car repair and maintenance', 'Car alarm supplier', 'Car stereo store', 'Window tinting service']",
#  "['Truck stop']",
#  "['Museum', 'Tourist attraction']",
#  "['Mental health clinic']",
#  "['Pain management physician']",
#  "['Shipping and mailing service', 'Business center', 'Fax service', 'Office supply store', 'Packaging supply store', 'Passport photo processor', 'Poster store', 'Print shop', 'Promotional products supplier', 'Sign shop']",
#  "['Cell phone store', 'Cell phone accessory store', 'Telecommunications service provider']",
#  "['Truck rental agency', 'Moving and storage service', 'Moving supply store', 'Packaging supply store', 'Self-storage facility', 'Trailer rental service', 'Trailer supply store', 'Used truck dealer', 'Van rental agency']",
#  "['Barber shop', 'Beauty salon']",
#  "['Mattress store', 'Bedding store', 'Bedroom furniture store', 'Furniture store']",
#  "['Beauty school', 'Beauty salon']",
#  "['Emergency room']",
#  "['Boat ramp']",
#  "['RV park', 'RV repair shop']",
#  "['Motorcycle shop', 'Motor scooter dealer', 'Motorcycle dealer', 'Motorcycle parts store', 'Motorcycle repair shop', 'Used motorcycle dealer']",
#  "['Hot dog restaurant']",
#  "['Tax department']",
#  "['Auto repair shop', 'Brake shop', 'Car repair and maintenance', 'Mechanic', 'Oil change service', 'Tire shop', 'Wheel alignment service']",
#  "['Liquor store', 'Beer store', 'Cigar shop', 'Tobacco shop', 'Vaporizer store', 'Wine store']",
#  "['Drug store', 'Convenience store', 'Cosmetics store']",
#  "['Orthopedic surgeon', 'Rehabilitation center', 'Sports medicine clinic']",
#  "['Beauty supply store', 'Variety store']",
#  "['Self-storage facility', 'Automobile storage facility', 'Boat storage facility', 'Moving supply store', 'RV storage facility', 'Storage facility']",
#  "['Motorcycle repair shop', 'Motorcycle dealer', 'Motorcycle parts store']",
#  "['Barber shop', 'Beauty salon', 'Hair salon', 'Hairdresser']",
#  "['Equipment rental agency']",
#  "['Butcher shop']",
#  "['Grocery store', 'Gas station']",
#  "['Salvage yard']",
#  "['Truck parts supplier', 'Auto parts store', 'Trailer supply store', 'Truck accessories store']",
#  "['Auto restoration service']",
#  "['HVAC contractor']",
#  "['Plastic products supplier']",
#  "['Calvary Chapel church']",
#  "['Insurance agency', 'Auto insurance agency', 'Home insurance agency', 'Insurance broker', 'Life insurance agency', 'Motorcycle insurance agency']",
#  "['Golf cart dealer']",
#  "['Wedding venue', 'Event venue']",
#  "['Attorney', 'Estate planning attorney', 'Family law attorney', 'Law firm', 'Personal injury attorney', 'Real estate attorney']",
#  "['Bar', 'Night club']",
#  "['Air conditioning repair service']",
#  "['Auto parts store', 'Trailer supply store', 'Truck accessories store']",
#  "['Federal credit union', 'ATM']",
#  "['Herb shop']",
#  "['Appliance repair service', 'Air conditioning repair service', 'Furnace repair service', 'Refrigerator repair service', 'Washer & dryer repair service']",
#  "['Transmission shop', 'Auto repair shop', 'Brake shop', 'Oil change service']",
#  "['Apartment complex', 'Apartment building', 'Apartment rental agency', 'Furnished apartment building', 'Student housing center']",
#  "['Non-denominational church']",
#  "['Painting studio', 'Aerated drinks supplier', 'Drawing lessons', 'Painting', 'Painting lessons']",
#  "['Landscaper', 'Service establishment']",
#  "['Computer support and services', 'Data recovery service']",
#  "['Martial arts school', 'Jujitsu school', 'Karate school']",
#  "['Cafe', 'Chinese restaurant']",
#  "['Parking lot']",
#  "['Gas cylinders supplier']",
#  "['Glass shop', 'Auto glass shop']",
#  "['University library', 'Library']",
#  "['Dentist', 'Cosmetic dentist', 'Dental clinic', 'Dental implants periodontist', 'Pediatric dentist', 'Teeth whitening service']",
#  "['Italian restaurant', 'Family restaurant', 'Pizza restaurant', 'Pizza Takeout', 'Restaurant']",
#  "['Auto repair shop', 'Auto wrecker', 'Gas shop', 'Repair service']",
#  "['Store', 'Herbal medicine store', 'Organic shop', 'Vitamin & supplements store']",
#  "['Wig shop']",
#  "['Plumber', 'Service establishment']",
#  "['Car wash', 'Self service car wash']",
#  "['Mosque']",
#  "['Housing development', 'Professional services']",
#  "['Cell phone store', 'Internet service provider', 'Telecommunications service provider']",
#  "['Cable company', 'Internet service provider', 'Security system supplier', 'Telephone company']",
#  "['Home builder']",
#  "['Laundry', 'Laundromat']",
#  "['Auto body shop', 'Auto dent removal service', 'Auto repair shop']",
#  "['Sunglasses store', 'Fashion accessories store', 'Gift shop', 'Shopping mall']",
#  "['Gastropub', 'Pub', 'Restaurant']",
#  "['Furniture store', 'Home goods store']",
#  "['Self-storage facility', 'Automobile storage facility', 'Boat storage facility', 'Moving supply store', 'Records storage facility', 'RV storage facility']",
#  "['Baptist church', 'Church', 'Federal credit union']",
#  "['Pain control clinic', 'Pain management physician']",
#  "['Lake']",
#  "['Plumbing supply store', 'Pipe supplier', 'Wholesaler']",
#  "['Mobile home park', 'Real estate']",
#  "['Medical clinic']",
#  '[\'Insurance agency\', \'Auto insurance agency\', \'Motorcycle insurance agency\', "Renter\'s insurance agency"]',
#  "['Tire shop', 'Auto electrical service', 'Auto repair shop', 'Brake shop', 'Car repair and maintenance', 'Mechanic', 'Oil change service', 'Transmission shop', 'Wheel alignment service', 'Wheel store']",
#  "['Supermarket']",
#  "['Southern restaurant (US)', 'Bar', 'Bistro', 'Cocktail bar', 'Restaurant']",
#  "['Computer store', 'Computer accessories store', 'Computer repair service', 'Computer support and services', 'Data recovery service']",
#  "['Eye care center', 'Optometrist', 'Sunglasses store']",
#  "['Business management consultant', 'Business development service', 'International trade consultant']",
#  "['Dollar store', 'Clothing store', 'Discount store', 'Discount supermarket', 'School supply store', 'Tobacco shop', 'Toy store']",
#  "['Shoe store', 'Boot store', 'Safety equipment supplier', 'Work clothes store']",
#  "['Chrysler dealer', 'Car manufacturer', 'Dodge dealer', 'Jeep dealer', 'Truck dealer', 'Used car dealer', 'Used truck dealer']",
#  "['Used auto parts store']",
#  "['Grocery store', 'Mexican restaurant']",
#  "['Mortgage lender', 'Mortgage broker']",
#  "['Antique store']",
#  "['Farm shop', 'Animal feed store', 'Hardware store']",
#  "['Pain management physician', 'Anesthesiologist', 'Doctor']",
#  "['Funeral home', 'Cremation service', 'Funeral director', 'Mortuary']",
#  "['Dollar store', 'Beer store', 'Clothing store', 'Discount store', 'Discount supermarket', 'School supply store', 'Tobacco shop', 'Toy store', 'Wine store']",
#  "['Auditorium']",
#  "['Seafood market', 'Dried seafood store', 'Seafood farm', 'Seafood wholesaler']",
#  "['Batting cage center', 'Sports complex']",
#  "['Wedding venue']",
#  "['Assisted living facility', 'Service establishment']",
#  "['Jewelry store', 'Boutique', 'Diamond buyer', 'Diamond dealer', 'Estate liquidator', 'Gold dealer', 'Jewelry designer', 'Jewelry repair service', 'Wedding service']",
#  "['Day spa']",
#  "['Club']",
#  "['Roofing contractor']",
#  "['Home inspector']",
#  "['Used car dealer', 'Auto repair shop']",
#  "['Paint store', 'Painter']",
#  "['Fitness center']",
#  "['Plastic surgeon', 'Surgeon', 'Surgical center']",
#  "['Historical landmark', 'Event venue', 'Tourist attraction', 'Wedding venue']",
#  "['Roofing contractor', 'Service establishment']",
#  "['Monogramming service', 'Embroidery service', 'Embroidery shop', 'Graphic designer']",
#  "['Wine store']",
#  "['Hair salon', 'Beauty salon', 'Beauty supply store', 'Hair extension technician', 'Hair extensions supplier', 'Stylist']",
#  "['Used car dealer', 'Car dealer', 'Used truck dealer']",
#  "['Used car dealer', 'Car dealer']",
#  "['Public medical center']",
#  "['Home builder', 'Housing development']",
#  "['Hair salon', 'Store']",
#  "['Appliance repair service']",
#  "['Chinese restaurant']",
#  "['Law firm', 'Legal services']",
#  "['Appliance store', 'Electronics store', 'Furniture store']",
#  "['Auto machine shop']",
#  "['Portrait studio', 'Photographer']",
#  "['Credit union']",
#  "['Bridal shop']",
#  "['Asian fusion restaurant', 'Latin American restaurant']",
#  "['Pizza restaurant', 'Restaurant']",
#  "['Tire shop', 'Wheel store']",
#  "['University']",
#  "['Car dealer', 'Kia dealer', 'Used car dealer']",
#  "['Cafeteria']",
#  "['Pharmacy', 'Drug store']",
#  "['Mattress store', 'Bedding store']",
#  "['Catholic church']",
#  "['Shipping service', 'Shipping and mailing service']",
#  "['Food processing company']",
#  "['Vitamin & supplements store']",
#  "['Veterinarian', 'Surgeon']",
#  "['Department of motor vehicles']",
#  "['School', 'Environmental program']",
#  "['Sandwich shop', 'Caterer', 'Restaurant']",
#  "['Boat storage facility', 'RV park', 'RV storage facility']",
#  "['Window tinting service']",
#  "['Physician assistant']",
#  "['Fuel supplier', 'Diesel fuel supplier']",
#  "['Boat dealer', 'Boat cover supplier', 'Boat repair shop']",
#  "['Denture care center']",
#  "['Mortgage lender']",
#  "['Spa', 'Nail salon']",
#  "['American restaurant', 'Restaurant']",
#  "['Car rental agency']",
#  "['Orthopedic surgeon', 'Doctor', 'Sports medicine physician']",
#  "['Disc golf course']",
#  "['Dollar store']",
#  "['Pumpkin patch']",
#  "['Softball field']",
#  "['Optometrist', 'Contact lenses supplier', 'Eye care center', 'Optician', 'Sunglasses store']",
#  "['Property management company', 'Apartment rental agency']",
#  "['Food court']",
#  "['Farm equipment supplier', 'Trailer dealer', 'Trailer repair shop']",
#  "['Dinner theater']",
#  "['Kennel', 'Dog day care center', 'Pet groomer']",
#  '["Women\'s clothing store", \'Clothing store\', \'Jeans shop\', \'Dress store\', \'Fashion accessories store\', \'Jewelry store\']',
#  "['Lounge']",
#  "['Employment center', 'Employment agency']",
#  "['Emergency care service', 'Emergency room']",
#  "['Urgent care center', 'Emergency care service', 'Medical clinic', 'Walk-in clinic']",
#  "['Urgent care center', 'Emergency care service', 'Family practice physician']",
#  "['Bathroom remodeler']",
#  "['Event venue', 'Banquet hall', 'Event planner', 'Market operator', 'Wedding venue']",
#  "['Restaurant', 'Caterer', 'Fast food restaurant', 'Sandwich shop']",
#  "['College', 'Non-profit organization', 'School', 'University']",
#  "['Corporate office', 'General contractor']",
#  "['Carpet store']",
#  "['Bar', 'Live music bar', 'Pool hall']",
#  "['Comedy club']",
#  "['Non-profit organization']",
#  "['Dance company']",
#  "['Convenience store', 'Pizza restaurant']",
#  "['Massage spa']",
#  '["Men\'s clothing store", \'Shoe store\', \'Uniform store\']',
#  "['Mattress store', 'Furniture store']",
#  "['Restaurant', 'Family restaurant', 'Italian restaurant', 'Pizza restaurant', 'Seafood restaurant']",
#  "['HVAC contractor', 'Air conditioning contractor', 'Air conditioning repair service', 'Heating contractor', 'Insulation contractor', 'Plumber', 'Pumping equipment and service']",
#  "['Mexican goods store']",
#  "['Car rental agency', 'Used car dealer']",
#  "['Uniform store']",
#  "['Country food restaurant']",
#  "['Physical fitness program', 'Fitness center', 'Gym', 'Indoor swimming pool', 'Swimming competition', 'Yoga instructor', 'Yoga studio']",
#  "['Video game store', 'Electronics store', 'Game store', 'Video store']",
#  "['Marketing agency']",
#  "['Discount store']",
#  "['Urgent care center', 'Emergency care service', 'Medical clinic']",
#  "['Auto radiator repair service']",
#  "['Optometrist', 'Optician']",
#  "['Towing service', 'Auto wrecker', 'Towing equipment provider']",
#  "['Store', 'Organic shop']",
#  "['Auto repair shop', 'Auto body shop', 'Towing service', 'Used car dealer']",
#  "['Auto parts store', 'Car accessories store', 'Car battery store', 'Tool rental service', 'Truck accessories store']",
#  "['Mattress store', 'Bedding store', 'Bedroom furniture store', 'Futon store']",
#  "['Adoption agency', 'Charity', 'Counselor', 'Thrift store']",
#  "['Towing service', 'Auto repair shop', 'Auto wrecker', 'Automobile storage facility', 'Crane service', 'Towing equipment provider', 'Truck repair shop', 'Vehicle shipping agent']",
#  "['Heating contractor', 'Air conditioning contractor', 'Air conditioning repair service', 'Air conditioning store', 'Air conditioning system supplier', 'Air duct cleaning service', 'Air filter supplier', 'Furnace repair service', 'Heating equipment supplier', 'HVAC contractor']",
#  "['Farm', 'Grocery store']",
#  "['Animal control service']",
#  '["Women\'s clothing store", "Children\'s clothing store", \'Plus size clothing store\', \'Shoe store\']',
#  "['Comic book store']",
#  "['Plumber']",
#  "['Cosmetics store', 'Beauty supply store']",
#  "['Auto body shop', 'Auto wrecker']",
#  "['Car dealer', 'Auto repair shop', 'Oil change service', 'Tire shop', 'Used car dealer']",
#  "['Computer repair service', 'Computer consultant', 'Computer service', 'Computer store', 'Computer support and services']",
#  "['Fishing pier']",
#  "['RV park', 'Campground', 'Hotel']",
#  "['Plumber', 'Electrician']",
#  "['Self-storage facility', 'Moving and storage service', 'Mover', 'Moving supply store']",
#  "['United Methodist church', 'Methodist church']",
#  "['Apartment rental agency', 'Apartments']",
#  "['Bakery', 'Cake shop', 'Cookie shop', 'Restaurant', 'Wedding bakery']",
#  "['Civic center']",
#  "['Car dealer', 'Auto parts store', 'Auto repair shop', 'Chevrolet dealer', 'GMC dealer', 'Transmission shop', 'Used car dealer']",
#  "['Plant nursery', 'Garden center', 'Landscaper']",
#  "['Legal services', 'Criminal justice attorney', 'Family law attorney']",
#  "['Motorcycle shop']",
#  "['Public health department']",
#  "['Episcopal church', 'Methodist church']",
#  "['Beauty salon', 'Barber shop', 'Hair salon']",
#  "['Electronics repair shop', 'Cell phone accessory store', 'Cell phone store', 'Computer repair service', 'Computer store', 'Computer support and services', 'Computer training school', 'Electronics store']",
#  "['Computer store']",
#  "['Flooring store', 'Carpet installer', 'Carpet store', 'Linoleum store', 'Wood floor installation service']",
#  "['Water utility company', 'Electric utility company']",
#  "['Bar', 'Club', 'Lounge', 'Night club', 'Pub']",
#  '[\'Insurance agency\', \'Auto insurance agency\', \'Commercial agent\', \'Home insurance agency\', \'Life insurance agency\', \'Motorcycle insurance agency\', "Renter\'s insurance agency"]',
#  "['Hamburger restaurant']",
#  "['Outdoor furniture store', 'Wholesaler']",
#  "['Candy store']",
#  "['Warehouse']",
#  "['Beauty supply store', 'Cosmetics store']",
#  "['Apartments']",
#  "['Farm shop', 'Flower market']",
#  "['Animal hospital', 'Dog care', 'Pet groomer', 'Pet sitter', 'Veterinarian']",
#  "['Diner']",
#  "['Motel', 'Hotel']",
#  "['State liquor store']",
#  "['Laboratory']",
#  '[\'Fashion accessories store\', "Children\'s clothing store", \'Clothing store\', "Men\'s clothing store", \'Shoe store\', "Women\'s clothing store"]',
#  "['Barbecue restaurant', 'Restaurant']",
#  "['Oral surgeon', 'Dental implants provider', 'Oral and maxillofacial surgeon']",
#  "['Coffee shop', 'Cafe', 'Coffee store', 'Espresso bar']",
#  "['Art center']",
#  "['GMC dealer', 'Car dealer']",
#  "['Plant nursery', 'Botanical garden', 'Garden center']",
#  "['Restaurant supply store', 'Appliance store', 'Brewing supply store', 'Cleaning products supplier', 'Industrial chemicals wholesaler', 'Kitchen supply store', 'Laundry']",
#  "['Department store', 'Bathroom supply store', 'Bedding store', 'Furniture store', 'Home goods store', 'Kitchen supply store', 'Linens store', 'Outdoor furniture store']",
#  "['Screen printer', 'Embroidery service', 'Engraver', 'Monogramming service', 'Sporting goods store', 'Trophy shop']",
#  "['Garbage dump', 'Garbage collection service']",
#  "['Barber shop', 'Beauty salon', 'Hair salon']",
#  "['Juice shop', 'Health food restaurant']",
#  "['Non-profit organization', 'Mission', 'Religious organization']",
#  "['Homeless shelter', 'Homeless service', 'Non-profit organization', 'Soup kitchen', 'Volunteer organization']",
#  "['Gas station', 'ATM', 'Car wash', 'Convenience store', 'Restaurant']",
#  "['Antique store', 'Antique furniture store', 'Furniture store', 'Home goods store']",
#  "['Credit union', 'ATM']",
#  "['Pub']",
#  "['Formal wear store', 'Boutique', 'Dress store', 'Tuxedo shop']",
#  "['Dentist', 'Cosmetic dentist', 'Dental clinic']",
#  "['Optometrist', 'Contact lenses supplier', 'Optician', 'Sunglasses store']",
#  "['Cannabis store', 'Art gallery', 'Boutique', 'Natural goods store']",
#  "['Landscaping supply store', 'Garden center', 'Mulch supplier', 'Plant nursery', 'Sod supplier', 'Stone supplier', 'Wholesale plant nursery']",
#  "['Equipment rental agency', 'Party equipment rental service', 'Tool rental service']",
#  "['Towing service', 'Auto repair shop', 'Auto wrecker', 'Chauffeur service', 'Crane service', 'Truck repair shop', 'Trucking company']",
#  "['Used book store', 'Book store']",
#  "['Auto repair shop', 'Muffler shop']",
#  "['Computer repair service', 'Computer consultant', 'Computer service', 'Computer store', 'Computer support and services', 'Computer training school', 'Data recovery service', 'Electronics repair shop', 'Television repair service', 'Used computer store']",
#  "['Medical clinic', 'Urgent care center']",
#  '[\'Boutique\', \'Clothing store\', \'Fashion accessories store\', \'Gift shop\', \'Jewelry store\', \'Shoe store\', "Women\'s clothing store"]',
#  "['Self-storage facility', 'Automobile storage facility', 'Boat storage facility', 'RV storage facility', 'Storage facility']",
#  "['Fashion accessories store', 'Ear piercing service', 'Jewelry store', 'Toy store']",
#  "['Towing service', 'Auto parts store']",
#  "['Transmission shop', 'Auto body shop']",
#  "['Physical therapy clinic', 'Physical therapist', 'Rehabilitation center', 'Sports medicine clinic']",
#  "['Heating contractor']",
#  "['RV storage facility', 'Boat storage facility', 'RV dealer', 'Recreational vehicle rental agency', 'RV repair shop']",
#  "['Chicken wings restaurant', 'Bar']",
#  '["Children\'s party service", \'Amusement center\']',
#  "['Community center', 'Auditorium']",
#  "['Indian restaurant', 'Buffet restaurant', 'Caterer', 'Halal restaurant', 'Lunch restaurant', 'Takeout Restaurant', 'Restaurant']",
#  "['Anime club']",
#  "['Bus company']",
#  "['Equipment rental agency', 'Contractor']",
#  '["Children\'s clothing store"]',
#  '["Children\'s clothing store", \'Shoe store\']',
#  "['Sandwich shop', 'Caterer']",
#  "['Orthopedic surgeon', 'Doctor']",
#  "['Car wash', 'Car detailing service']",
#  "['Apartment building', 'Apartment complex', 'Apartment rental agency', 'Condominium complex', 'Condominium rental agency', 'Real estate rental agency']",
#  "['Martial arts school', 'Fitness center']",
#  "['Pediatric dentist', 'Dental clinic']",
#  "['Plumber', 'Septic system service']",
#  "['Veterans affairs department']",
#  "['Equestrian facility']",
#  "['HVAC contractor', 'Air conditioning contractor', 'Air conditioning repair service', 'Heating contractor']",
#  "['Metal fabricator']",
#  "['Non-profit organization', 'Art gallery']",
#  "['Auto wrecker', 'Towing service']",
#  "['Grocery store', 'Supermarket']",
#  "['Antique store', 'Architectural salvage store', 'Collectibles store', 'Flea market', 'Home goods store', 'Natural goods store']",
#  "['Flooring store', 'Flooring contractor', 'Wood and laminate flooring supplier']",
#  "['Post office', 'Logistics service', 'Money order service', 'Passport office', 'Shipping and mailing service']",
#  "['Dry cleaner', 'Laundromat']",
#  "['Pharmacy', 'Drug store', 'Medical supply store', 'Vitamin & supplements store']",
#  "['Cabin rental agency']",
#  "['Truck dealer']",
#  "['Mission']",
#  "['Community college']",
#  '["Driver\'s license office"]',
#  "['Law firm', 'Bankruptcy attorney', 'Employment attorney', 'Social security attorney']",
#  "['Caterer', 'American restaurant', 'Cafe', 'Chicken restaurant', 'Event planner', 'Event venue', 'Party planner', 'Pizza restaurant', 'Salad shop', 'Wedding service']",
#  "['Takeout Restaurant', 'Delivery Restaurant']",
#  "['Bar', 'Dart bar', 'Live music bar', 'Pool hall']",
#  "['Loan agency', 'Tax preparation']",
#  "['Radiator shop', 'Radiator repair service', 'Truck repair shop']",
#  "['Restaurant', 'Fast food restaurant', 'Hamburger restaurant']",
#  "['Boat repair shop', 'Outboard motor store']",
#  "['Personal injury attorney']",
#  "['Software company', 'Repairs']",
#  "['News service']",
#  "['Fast food restaurant', 'Hamburger restaurant', 'Restaurant']",
#  "['Dollar store', 'Beauty supply store', 'Discount store', 'Grocery store', 'Party store']",
#  "['Car detailing service']",
#  "['Aerospace company', 'Business center']",
#  "['Construction equipment supplier', 'Construction machine dealer', 'Equipment supplier', 'Farm equipment supplier', 'Industrial equipment supplier', 'Lawn mower store', 'Mining equipment', 'Tractor dealer']",
#  "['Self-storage facility', 'Boat storage facility', 'RV storage facility']",
#  "['Gym', 'Personal trainer', 'Physical fitness program', 'Tanning salon']",
#  "['Cookie shop', 'Bakery', 'Cake shop', 'Dessert restaurant', 'Dessert shop', 'Restaurant']",
#  "['Dog trainer', 'Dog day care center', 'Dog park', 'Dog walker', 'Pet boarding service', 'Pet sitter', 'Pet store', 'Pet trainer']",
#  "['Gym', 'Exercise equipment store']",
#  "['Dermatologist', 'Medical spa']",
#  "['Sign shop', 'Banner store', 'Custom label printer', 'Event management company', 'Graphic designer', 'Poster store']",
#  "['Charity']",
#  "['Tour agency']",
#  "['Towing service', 'Auto repair shop', 'Auto wrecker', 'Used auto parts store']",
#  "['Dentist', 'Cosmetic dentist']",
#  "['Physical fitness program']",
#  "['Locksmith']",
#  "['Flooring store']",
#  "['Plumber', 'Bathroom remodeler', 'Service establishment']",
#  "['Telecommunications service provider', 'Cell phone store']",
#  "['Pest control service', 'Contractor', 'Environmental health service', 'Home inspector']",
#  "['Real estate developer']",
#  "['Heating contractor', 'Air conditioning contractor', 'Contractor']",
#  "['Addiction treatment center']",
#  "['Used car dealer', 'Store']",
#  "['Animal feed store']",
#  "['Shooting range']",
#  "['Condominium complex', 'Real estate']",
#  "['Football Field']",
#  "['Park', 'Community center']",
#  "['Lawn mower store', 'Lawn mower repair service', 'Small engine repair service']",
#  "['Fireworks supplier']",
#  "['Auto repair shop', 'Car repair and maintenance']",
#  "['Jewelry store', 'Boutique', 'Fashion accessories store', 'Gift shop', 'Jeweler', 'Jewelry designer']",
#  "['Library']",
#  "['Massage spa', 'Massage therapist']",
#  "['Car racing track']",
#  "['Formal wear store']",
#  "['Cell phone store', 'Cell phone accessory store', 'Mobile phone repair shop']",
#  "['Law firm']",
#  "['Flooring store', 'Cabinet store', 'Carpet installer', 'Carpet store', 'Tile store', 'Wood and laminate flooring supplier', 'Wood floor installation service']",
#  "['Place of worship', 'Tourist attraction']",
#  "['Self-storage facility', 'Boat storage facility', 'Moving and storage service', 'Moving supply store', 'Records storage facility', 'Storage facility']",
#  "['Home builder', 'Real estate agency', 'Real estate developer']",
#  "['Shipping and mailing service']",
#  "['Donut shop', 'Coffee shop']",
#  "['Hotel', 'Motel']",
#  '["Women\'s clothing store", \'Clothing store\', \'Jeans shop\', \'Dress store\', \'Outerwear store\', \'Shoe store\']',
#  "['Carpet cleaning service', 'Commercial cleaning service', 'Upholstery cleaning service']",
#  "['Septic system service']",
#  "['Auto body shop', 'Auto repair shop', 'Auto wrecker', 'Towing service']",
#  "['Anesthesiologist']",
#  "['Uniform store', 'Medical supply store']",
#  '["Women\'s clothing store", \'Clothing store\', \'Fashion accessories store\', \'Jewelry store\', \'Shoe store\']',
#  "['Pharmacy', 'Boutique', 'Ice cream shop', 'Store', 'Toy store']",
#  "['Veterinary care']",
#  "['Septic system service', 'Service establishment']",
#  "['Fast food restaurant']",
#  "['Hardware store', 'Lumber store']",
#  "['Credit union', 'ATM', 'Federal credit union', 'Investment service', 'Mortgage lender']",
#  "['Medical office', 'Doctor', 'Surgeon']",
#  "['Rheumatologist']",
#  "['Apartment building', 'Apartment complex', 'Property management company']",
#  "['County court']",
#  "['General practice attorney', 'Bankruptcy attorney', 'Criminal justice attorney', 'Divorce lawyer', 'Estate planning attorney', 'Family law attorney', 'Attorney', 'Legal services']",
#  "['Gym', 'Fitness center', 'Personal trainer', 'Spa and health club', 'Tanning salon']",
#  "['Truck parts supplier']",
#  "['Endocrinologist']",
#  "['Wine store', 'Beer store', 'Candy store', 'Home goods store']",
#  "['ATV dealer', 'Honda dealer', 'Motorcycle dealer', 'Motorcycle parts store', 'Repair service']",
#  "['Engineering consultant', 'Engineer']",
#  "['Self-storage facility', 'Moving and storage service']",
#  "['Orthodontist']",
#  "['Dry ice supplier']",
#  "['Auto upholsterer']",
#  "['Apartment complex', 'Apartment building', 'Furnished apartment building']",
#  "['Gutter cleaning service']",
#  "['Marina']",
#  "['Lodging']",
#  "['Furniture store', 'Interior designer']",
#  "['House cleaning service', 'Cleaning service', 'Janitorial service']",
#  "['Tire shop', 'Auto body shop', 'Mechanic']",
#  "['Historical landmark']",
#  "['Auto body shop', 'Auto air conditioning service', 'Towing service', 'Window installation service']",
#  "['Gift shop', 'Caterer', 'Chocolate shop', 'Dessert shop', 'Florist', 'Gift basket store', 'Juice shop']",
#  "['Wine store', 'Services']",
#  "['Bridal shop', 'Dress store', 'Formal wear store', 'Tuxedo shop', 'Wedding store']",
#  "['Beauty salon', 'Gym', 'Tanning salon']",
#  "['Chiropractor', 'Massage therapist', 'Pain management physician']",
#  "['General store']",
#  "['Physical fitness program', 'Gym']",
#  "['Veterans hospital', 'Hospital']",
#  "['Truck repair shop', 'Tire shop', 'Towing service']",
#  "['Sports medicine physician', 'Orthopedic clinic']",
#  "['Real estate agency', 'Real estate consultant']",
#  "['HVAC contractor', 'Air conditioning contractor', 'Air conditioning repair service', 'Commercial refrigeration', 'Heating contractor']",
#  "['Security guard service']",
#  "['Baking supply store']",
#  "['Custom home builder', 'Home builder']",
#  "['Auto body parts supplier', 'Auto parts store']",
#  "['Auto repair shop', 'Car battery store', 'Car repair and maintenance', 'Oil change service', 'Oil refinery', 'Tire shop', 'Wheel alignment service']",
#  "['Appliance repair service', 'Appliance parts supplier', 'Microwave oven repair service', 'Refrigerator repair service', 'Repair service', 'Small appliance repair service', 'Washer & dryer repair service']",
#  "['Laundry']",
#  "['Hair salon', 'Beauty salon', 'Hair extension technician', 'Hair extensions supplier', 'Make-up artist', 'Hairdresser']",
#  "['Bankruptcy attorney', 'Personal injury attorney', 'Social security attorney']",
#  "['Urgent care center']",
#  "['Real estate agency', 'Commercial real estate agency', 'Real estate consultant']",
#  "['Cosmetics store']",
#  "['Blood donation center', 'Blood bank']",
#  "['Pet groomer', 'Pet boarding service']",
#  "['Auto body shop', 'Auto glass shop', 'Auto repair shop', 'Car repair and maintenance']",
#  "['Credit union', 'ATM', 'Federal credit union']",
#  "['Hair removal service', 'Beauty salon', 'Facial spa', 'Waxing hair removal service']",
#  "['Tire shop', 'Used tire shop', 'Wheel store']",
#  "['Low income housing program']",
#  "['Hot dog restaurant', 'Restaurant']",
#  "['Beauty salon', 'Nail salon']",
#  ...]
