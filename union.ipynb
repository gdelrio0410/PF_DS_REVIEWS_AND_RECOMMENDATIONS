# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
sitio=pd.read_csv("Sitios_Unidos.csv")

# %%
sitio.head(5)
# Out:
#                 category  avg_rating                                gmap_id  \
# 0           ['Pharmacy']         4.9  0x88f16e41928ff687:0x883dad4fd048e8f8
# 1   ['Textile exporter']         4.5  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9
# 2  ['Korean restaurant']         4.4  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3       ['Fabric store']         3.3   0x80c2c89923b27a41:0x32041559418d447
# 4       ['Fabric store']         4.3  0x80c2c632f933b073:0xc31785961fe826a6
#
#                name
# 0   Porter Pharmacy
# 1      City Textile
# 2      San Soo Dang
# 3      Nova Fabrics
# 4  Nobel Textile Co

# %%
sitio=sitio[["category","avg_rating","gmap_id","name"]]

# %%
sitio.isnull().count()
# Out:
# category      3025011
# avg_rating    3025011
# gmap_id       3025011
# name          3025011
# dtype: int64

# %%
sitio
# Out:
#                                                   category  avg_rating  \
# 0                                             ['Pharmacy']         4.9
# 1                                     ['Textile exporter']         4.5
# 2                                    ['Korean restaurant']         4.4
# 3                                         ['Fabric store']         3.3
# 4                                         ['Fabric store']         4.3
# ...                                                    ...         ...
# 3025006                              ['Restaurant', 'Bar']         4.6
# 3025007                               ['Trucking company']         4.2
# 3025008                     ['Beauty salon', 'Hair salon']         4.7
# 3025009  ['Truck accessories store', 'Powder coating se...         4.6
# 3025010                                     ['Campground']         4.2
#
#                                        gmap_id  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8
# ...

# %%
Estado=pd.read_csv("Estados.csv")

# %%
Estado=Estado[["gmap_id","Estado"]]

# %%
Estado
# Out:
#                                        gmap_id      Estado
# 0        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf     Alabama
# 1        0x886268e8fdc4fd2f:0x746533eb9aa4d4df     Alabama
# 2        0x8889aeaec69d4d49:0xb5c343f9d441acf2     Alabama
# 3        0x88626b2e333be6d9:0x2a00a09a7045984f     Alabama
# 4         0x88890c0ff1fb3a1d:0x2b4463747ed6a8a     Alabama
# ...                                        ...         ...
# 1458618  0x54905ea486e1817f:0xc96b16d3a19c2630  Washington
# 1458619  0x5490f7c23e557ca3:0x9ab5bc936ace4a3b  Washington
# 1458620  0x5490594f83e49d6d:0x4e77bd04e0fd72f8  Washington
# 1458621  0x54905e98e7d5f58d:0xa93f0e72b84ee40b  Washington
# 1458622  0x5490f8388d138169:0xc64616ee8cb521ec  Washington
#
# [1458623 rows x 2 columns]

# %%
Dataframe = pd.merge(Estado,sitio, on='gmap_id')

# %%
Dataframe.to_csv("Union.csv")

# %%
Dataframe
# Out:
#                                        gmap_id      Estado  \
# 0        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf     Alabama
# 1        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf     Alabama
# 2        0x886268e8fdc4fd2f:0x746533eb9aa4d4df     Alabama
# 3        0x886268e8fdc4fd2f:0x746533eb9aa4d4df     Alabama
# 4        0x8889aeaec69d4d49:0xb5c343f9d441acf2     Alabama
# ...                                        ...         ...
# 1084599  0x5490550bf74a2a4d:0xdffe9bd523a53f1e  Washington
# 1084600  0x5491004195a77427:0x51bf13430c3ff249  Washington
# 1084601  0x5491014d6fbcd7fd:0xe027823a9d0e4ecf  Washington
# 1084602  0x54923990302cb3c7:0x10f023b56efdb019  Washington
# 1084603  0x54906ab43fffffff:0x69acbd12df532b6c  Washington
#
#                                                   category  avg_rating  \
# 0                                             ['Boutique']         4.6
# 1                                             ['Boutique']         4.6
# ...

# %%
Dataframe.dropna(subset=["category"], inplace=True)

# %%
def filtrar_dataframe(dataframe, columna, frase):
    nuevo_dataframe = dataframe[dataframe[columna].str.contains(frase)]
    return nuevo_dataframe

# %%
data=filtrar_dataframe(Dataframe,"category","restaurant")

# %%
def sacar(i):
    i=i.str.replace("[","")
    i=i.str.replace("]","")
    i=i.str.replace("'","")
  
    return i

# %%
data.dropna(subset=["category"], inplace=True)
category=pd.DataFrame(data["category"].astype(str))
category=category.apply(sacar, axis=1)
data=data.drop("category",axis=1)
data.insert(4, "category", category)
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_8096\3462840825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(subset=["category"], inplace=True)

# %%
data
# Out:
#                                        gmap_id      Estado  avg_rating  \
# 12       0x8889221157fb3455:0x5c125c40c3eccc2a     Alabama         4.1
# 13       0x8889221157fb3455:0x5c125c40c3eccc2a     Alabama         4.1
# 14       0x88892bb449d44cb3:0x7beaf0b2e3171a49     Alabama         3.2
# 15       0x88892bb449d44cb3:0x7beaf0b2e3171a49     Alabama         3.2
# 18       0x888cedd24b6af451:0x9958558c300844df     Alabama         4.0
# ...                                        ...         ...         ...
# 1084531  0x5491756b249e98c1:0xea99e1c578941d55  Washington         4.7
# 1084536  0x5484dc6cf214971d:0xa2eba48db316e005  Washington         4.2
# 1084542  0x5362240bf2b1e7b5:0xcbc6b7a3acd302b9  Washington         4.1
# 1084545  0x549007ac435e001d:0xc180eee6ba73b7ef  Washington         4.6
# 1084554  0x54906ff2af973d71:0x552e8f142c66e8a7  Washington         3.8
#
#                                                     name  \
# ...

# %%
df=data[data['Estado'] == "Florida"]
df=df[df['category'] == "Chicken restaurant"]

sns.countplot(y='name', data=df, order=df['name'].value_counts().head(5).index)
# Out:
# c:\Users\victo\OneDrive\Escritorio\Tra_Final\PF_DS_REVIEWS_AND_RECOMMENDATIONS\tr\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\victo\OneDrive\Escritorio\Tra_Final\PF_DS_REVIEWS_AND_RECOMMENDATIONS\tr\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='count', ylabel='name'>

# %%
# Out:
# c:\Users\victo\OneDrive\Escritorio\Tra_Final\PF_DS_REVIEWS_AND_RECOMMENDATIONS\tr\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\victo\OneDrive\Escritorio\Tra_Final\PF_DS_REVIEWS_AND_RECOMMENDATIONS\tr\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='count', ylabel='name'>

# %%
lista=list(data["category"].unique())
lista
# Out:
# ['Pizza restaurant',
#  'Pizza delivery, Chicken wings restaurant, Pizza restaurant, Pizza Takeout',
#  'Asian fusion restaurant, Dessert restaurant',
#  'Fast food restaurant, Breakfast restaurant, Burrito restaurant, Lunch restaurant, Takeout Restaurant, Mexican restaurant, Restaurant, Taco restaurant, Tex-Mex restaurant, Vegetarian restaurant',
#  'American restaurant',
#  'Health food restaurant',
#  'Chicken restaurant, Restaurant',
#  'Barbecue restaurant',
#  'Juice shop, Raw food restaurant, Salad shop, Vegan restaurant',
#  'Sandwich shop, Caterer, Fast food restaurant, Takeout Restaurant, Restaurant',
#  'Seafood restaurant',
#  'Chicken restaurant, American restaurant, Cheesesteak restaurant, Fast food restaurant',
#  'Mexican restaurant',
#  'Pizza restaurant, Italian restaurant, Delivery Restaurant, Takeout Restaurant, Pizza delivery, Pizza Takeout',
#  'Italian restaurant, Brunch restaurant, Cocktail bar, Wine bar',
# ...

# %%
sns.countplot(x='category', data=df, order=df['category'].value_counts().head(5).index)

# %%
def Estado_Rest(data,estado):
    
    df=data[data['Estado'] == estado]
    df=pd.DataFrame(df)
    df=sns.countplot(y='category', data=df, order=df['category'].value_counts().head(5).index)

    
    return df

# %%
df=Estado_Rest(data,"Florida")
# Out:
# c:\Users\victo\OneDrive\Escritorio\Tra_Final\PF_DS_REVIEWS_AND_RECOMMENDATIONS\tr\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\victo\OneDrive\Escritorio\Tra_Final\PF_DS_REVIEWS_AND_RECOMMENDATIONS\tr\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
list(data["category"].unique())
# Out:
# ["['Pizza restaurant']",
#  "['Pizza delivery', 'Chicken wings restaurant', 'Pizza restaurant', 'Pizza Takeout']",
#  "['Asian fusion restaurant', 'Dessert restaurant']",
#  "['Fast food restaurant', 'Breakfast restaurant', 'Burrito restaurant', 'Lunch restaurant', 'Takeout Restaurant', 'Mexican restaurant', 'Restaurant', 'Taco restaurant', 'Tex-Mex restaurant', 'Vegetarian restaurant']",
#  "['American restaurant']",
#  "['Health food restaurant']",
#  "['Chicken restaurant', 'Restaurant']",
#  "['Barbecue restaurant']",
#  "['Juice shop', 'Raw food restaurant', 'Salad shop', 'Vegan restaurant']",
#  "['Sandwich shop', 'Caterer', 'Fast food restaurant', 'Takeout Restaurant', 'Restaurant']",
#  "['Seafood restaurant']",
#  "['Chicken restaurant', 'American restaurant', 'Cheesesteak restaurant', 'Fast food restaurant']",
#  "['Mexican restaurant']",
#  "['Pizza restaurant', 'Italian restaurant', 'Delivery Restaurant', 'Takeout Restaurant', 'Pizza delivery', 'Pizza Takeout']",
# ...
